# %% [markdown]
# <h1 style="text-align:center; font-size:40px"><u>Approximate Gaussian Processes</u></h1>

# %%
# @hidden
from IPython.display import HTML
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('.cm-comment:contains(@hidden)').closest('div.input').hide();
 } else {
 $('.cm-comment:contains(@hidden)').closest('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<b>Some of the code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the hidden cells, click <a href="javascript:code_toggle()">here</a>.</b>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('.cm-comment:contains(@hidden)').closest('div.input').hide();
#  } else {
#  $('.cm-comment:contains(@hidden)').closest('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <b>Some of the code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the hidden cells, click <a href="javascript:code_toggle()">here</a>.</b>

# %% [markdown]
# <h1><u>Bayesian Inference</u></h1>

# %% [markdown]
# **Objective:** For a set of observations $y_i = f(x_i) + \epsilon$, $\epsilon \sim N(0, \sigma^2_n)$, <span style="color:red">**find the posterior distribution over functions text**</span> $p(f(\cdot)|x,y)$ that explains the data.<br>

# %% [markdown]
# **Bayes Theorem**:

# %%
#@hidden
HTML('''
<script>
$('.BayesPost').hover(
  function(){
        $('.BayesPost').css({"background":"white", "color":"blue"});
  },function(){
        $('.BayesPost').css({"background":"white", "color":"black"});
});
$('.BayesLike').hover(
  function(){
        $('.BayesLike').css({"background":"white", "color":"#0cb500"});
  },function(){
        $('.BayesLike').css({"background":"white", "color":"black"});
});
$('.BayesPrior').hover(
  function(){
        $('.BayesPrior').css({"background":"white", "color":"red"});
  },function(){
        $('.BayesPrior').css({"background":"white", "color":"black"});
});
$('.BayesMarg').hover(
  function(){
        $('.BayesMarg').css({"background":"white", "color":"#ff7b00"});
  },function(){
        $('.BayesMarg').css({"background":"white", "color":"black"});
});
</script>
<table  style="margin-left: auto; margin-right: auto;font-size:16px">
    <tr style="background-color:white;">
        <td rowspan = 2 class="BayesPost">$$p(\mathbf{f}|\mathbf{x},\mathbf{y})$$</td>
        <td rowspan = 2 >$$=$$</td>
        <td style = "border-bottom: 1px solid #000;padding: 0px 7px;" class="BayesLike">$$p(\mathbf{y}|\mathbf{f})$$</td>
        <td style = "border-bottom: 1px solid #000;padding: 0px 7px;" class="BayesPrior">$$p(\mathbf{f})$$</td>
    </tr>
    <tr style="background-color:white;">
        <td colspan = 2 class="BayesMarg">$$\qquad p(\mathbf{y})$$</td>
    </tr>
</table>''')
# Out:
# <script>
# $('.BayesPost').hover(
#   function(){
#         $('.BayesPost').css({"background":"white", "color":"blue"});
#   },function(){
#         $('.BayesPost').css({"background":"white", "color":"black"});
# });
# $('.BayesLike').hover(
#   function(){
#         $('.BayesLike').css({"background":"white", "color":"#0cb500"});
#   },function(){
#         $('.BayesLike').css({"background":"white", "color":"black"});
# });
# $('.BayesPrior').hover(
#   function(){
#         $('.BayesPrior').css({"background":"white", "color":"red"});
#   },function(){
#         $('.BayesPrior').css({"background":"white", "color":"black"});
# });
# $('.BayesMarg').hover(
#   function(){
#         $('.BayesMarg').css({"background":"white", "color":"#ff7b00"});
#   },function(){
#         $('.BayesMarg').css({"background":"white", "color":"black"});
# });
# </script>
# <table  style="margin-left: auto; margin-right: auto;font-size:16px">
#     <tr style="background-color:white;">
# ...

# %% [markdown]
# <h3>Bayesian Inference in Gaussian Processes (GPs)</h3>

# %%
#@hidden
HTML('''
<script>
$('.BayesPost').hover(
  function(){
        $('.BayesPost').css({"background":"white", "color":"blue"});
  },function(){
        $('.BayesPost').css({"background":"white", "color":"black"});
});
$('.BayesLike').hover(
  function(){
        $('.BayesLike').css({"background":"white", "color":"#0cb500"});
  },function(){
        $('.BayesLike').css({"background":"white", "color":"black"});
});
$('.BayesPrior').hover(
  function(){
        $('.BayesPrior').css({"background":"white", "color":"red"});
  },function(){
        $('.BayesPrior').css({"background":"white", "color":"black"});
});
$('.BayesMarg').hover(
  function(){
        $('.BayesMarg').css({"background":"white", "color":"#ff7b00"});
  },function(){
        $('.BayesMarg').css({"background":"white", "color":"black"});
});
</script>
<table  style="margin-left: auto; margin-right: auto;font-size:16px">
    <tr style="background-color:white;">
        <td rowspan = 2 class="BayesPost">$$p(\mathbf{f}, \mathbf{f_*}|\mathbf{y})$$</td>
        <td rowspan = 2 >$$=$$</td>
        <td style = "border-bottom: 1px solid #000;padding: 0px 7px;" class="BayesLike">$$p(\mathbf{y}|\mathbf{f})$$</td>
        <td style = "border-bottom: 1px solid #000;padding: 0px 7px;" class="BayesPrior">$$p(\mathbf{f}, \mathbf{f_*})$$</td>
    </tr>
    <tr style="background-color:white;">
        <td colspan = 2 class="BayesMarg">$$\qquad p(\mathbf{y})$$</td>
    </tr>
</table>''')
# Out:
# <script>
# $('.BayesPost').hover(
#   function(){
#         $('.BayesPost').css({"background":"white", "color":"blue"});
#   },function(){
#         $('.BayesPost').css({"background":"white", "color":"black"});
# });
# $('.BayesLike').hover(
#   function(){
#         $('.BayesLike').css({"background":"white", "color":"#0cb500"});
#   },function(){
#         $('.BayesLike').css({"background":"white", "color":"black"});
# });
# $('.BayesPrior').hover(
#   function(){
#         $('.BayesPrior').css({"background":"white", "color":"red"});
#   },function(){
#         $('.BayesPrior').css({"background":"white", "color":"black"});
# });
# $('.BayesMarg').hover(
#   function(){
#         $('.BayesMarg').css({"background":"white", "color":"#ff7b00"});
#   },function(){
#         $('.BayesMarg').css({"background":"white", "color":"black"});
# });
# </script>
# <table  style="margin-left: auto; margin-right: auto;font-size:16px">
#     <tr style="background-color:white;">
# ...

# %% [markdown]
# **The Prior (Noiseless and Noisy)**

# %%
#@hidden
HTML('''
<script>
$('.a').hover(
  function(){
        $('.a').css({"background":"white", "color":"blue"});
  },function(){
        $('.a').css({"background":"white", "color":"black"});
});
$('.b').hover(
  function(){
        $('.b').css({"background":"white", "color":"green"});
  },function(){
        $('.b').css({"background":"white", "color":"black"});
});
$('.c').hover(
  function(){
        $('.c').css({"background":"white", "color":"#ab4d00"});
  },function(){
        $('.c').css({"background":"white", "color":"black"});
});
$('.d').hover(
  function(){
        $('.d').css({"background":"white", "color":"#00b8ae"});
  },function(){
        $('.d').css({"background":"white", "color":"black"});
});
$('.BayesPrior').hover(
  function(){
        $('.BayesPrior').css({"background":"white", "color":"red"});
  },function(){
        $('.BayesPrior').css({"background":"white", "color":"black"});
});
$('.BayesLike').hover(
  function(){
        $('.BayesLike').css({"background":"white", "color":"#0cb500"});
  },function(){
        $('.BayesLike').css({"background":"white", "color":"black"});
});
</script>
<table style="margin-left: auto; margin-right: auto;">
    <tr>
        <th colspan="11" style="text-align: center;">GP (Noiseless)</th>
        <th colspan="2" style="text-align: center;">Approximation</th>
    </tr>
    <tr style="background-color:white;">
        <td rowspan = 2 class = "BayesPrior" >$$\Bigg[ \matrix{ \mathbf{f} \cr \mathbf{f_*}} \Bigg]$$</td>
        <td rowspan = 2 >$$\sim N \Bigg($$</td>
        <td rowspan = 2 >$$\Bigg[$$</td>
        <td >$$\mathbf{0}$$</td>
        <td rowspan = 2 >$$\Bigg]$$</td>
        <td rowspan = 2 style="font-size:15px">,</td>
        <td rowspan = 2 >$$\Bigg[$$</td>
        <td class = "a" >$$K(\mathbf{x},\mathbf{x})$$</td>
        <td class = "b" >$$K(\mathbf{x},\mathbf{x_*})$$</td>
        <td rowspan = 2 >$$\Bigg]$$</td>
        <td rowspan = 2 >$$\Bigg)$$</td>
        <td >Approximate</td>
        <td class = "BayesPrior" >$p(\mathbf{f},\mathbf{f_*})$</td>
    </tr>
    <tr style="background-color:white;">
        <td >$$\mathbf{0}$$</td>
        <td class = "c" >$$K(\mathbf{x_*},\mathbf{x})$$</td>
        <td class = "d" >$$K(\mathbf{x_*},\mathbf{x_*})$$</td>
        <td > With inducing prior</td>
        <td class = "BayesPrior" >$q(\mathbf{f},\mathbf{f_*})$</td>
    </tr>
</table>
<table style="margin-left: auto; margin-right: auto;table-layout:fixed;">
    <tr>
        <th colspan="11" style="text-align: center;">GP (Noisy)</th>
        <th colspan="2" style="text-align: center;">Approximation</th>
    </tr>
    <tr style="background-color:white;">
        <td rowspan = 2 class = "BayesPrior" >$$\Bigg[ \matrix{ \mathbf{y} \cr \mathbf{f_*}} \Bigg]$$</td>
        <td rowspan = 2 >$$\sim N \Bigg($$</td>
        <td rowspan = 2 >$$\Bigg[$$</td>
        <td >$$\mathbf{0}$$</td>
        <td rowspan = 2 >$$\Bigg]$$</td>
        <td rowspan = 2 style="font-size:15px">,</td>
        <td rowspan = 2 >$$\Bigg[$$</td>
        <td class = "BayesLike" style="width:10px">$$K(\mathbf{x},\mathbf{x}) + \sigma_n^2 I$$</td>
        <td class = "b" >$$K(\mathbf{x},\mathbf{x_*})$$</td>
        <td rowspan = 2 >$$\Bigg]$$</td>
        <td rowspan = 2 >$$\Bigg)$$</td>
        <td >Exact likelihood</td>
        <td class = "BayesLike" >$p(\mathbf{y} | \mathbf{f})$</td>
    </tr>
    <tr style="background-color:white;">
        <td >$$\mathbf{0}$$</td>
        <td class = "c" >$$K(\mathbf{x_*},\mathbf{x})$$</td>
        <td class = "d" >$$K(\mathbf{x_*},\mathbf{x_*})$$</td>
        <td > With inducing prior</td>
        <td class = "BayesPrior" >$q(\mathbf{y},\mathbf{f_*})$</td>
    </tr>
</table>
''')
# Out:
# <script>
# $('.a').hover(
#   function(){
#         $('.a').css({"background":"white", "color":"blue"});
#   },function(){
#         $('.a').css({"background":"white", "color":"black"});
# });
# $('.b').hover(
#   function(){
#         $('.b').css({"background":"white", "color":"green"});
#   },function(){
#         $('.b').css({"background":"white", "color":"black"});
# });
# $('.c').hover(
#   function(){
#         $('.c').css({"background":"white", "color":"#ab4d00"});
#   },function(){
#         $('.c').css({"background":"white", "color":"black"});
# });
# $('.d').hover(
#   function(){
#         $('.d').css({"background":"white", "color":"#00b8ae"});
#   },function(){
#         $('.d').css({"background":"white", "color":"black"});
# });
# $('.BayesPrior').hover(
#   function(){
#         $('.BayesPrior').css({"background":"white", "color":"red"});
#   },function(){
#         $('.BayesPrior').css({"background":"white", "color":"black"});
# });
# $('.BayesLike').hover(
# ...

# %% [markdown]
# **Posterior Predictive Distribution** <br>
# We undertake exact inference by marginalising out the latent functions $f$ to find get the posterior predictive distribution

# %%
# @hidden
HTML('''
<script>
$('.BayesPost').hover(
  function(){
        $('.BayesPost').css({"background":"white", "color":"blue"});
  },function(){
        $('.BayesPost').css({"background":"white", "color":"black"});
});
$('.PostPred').hover(
  function(){
        $('.PostPred').css({"background":"white", "color":"#00a6ff"});
  },function(){
        $('.PostPred').css({"background":"white", "color":"black"});
});
$('.a').hover(
  function(){
        $('.a').css({"background":"white", "color":"blue"});
  },function(){
        $('.a').css({"background":"white", "color":"black"});
});
$('.b').hover(
  function(){
        $('.b').css({"background":"white", "color":"green"});
  },function(){
        $('.b').css({"background":"white", "color":"black"});
});
$('.c').hover(
  function(){
        $('.c').css({"background":"white", "color":"#ab4d00"});
  },function(){
        $('.c').css({"background":"white", "color":"black"});
});
$('.d').hover(
  function(){
        $('.d').css({"background":"white", "color":"#00b8ae"});
  },function(){
        $('.d').css({"background":"white", "color":"black"});
});
$('.BayesPrior').hover(
  function(){
        $('.BayesPrior').css({"background":"white", "color":"red"});
  },function(){
        $('.BayesPrior').css({"background":"white", "color":"black"});
});
$('.BayesLike').hover(
  function(){
        $('.BayesLike').css({"background":"white", "color":"#0cb500"});
  },function(){
        $('.BayesLike').css({"background":"white", "color":"black"});
});
$('.BayesMarg').hover(
  function(){
        $('.BayesMarg').css({"background":"white", "color":"#ff7b00"});
  },function(){
        $('.BayesMarg').css({"background":"white", "color":"black"});
});
</script>
<table style="margin-left: auto; margin-right: auto;font-size:16px">
    <tr style="background-color:white;">
        <td class = "PostPred">$$p(\mathbf{f_*}|\mathbf{y})$$</td>
        <td >$$=\int$$</td>
        <td class = "BayesPost">$$p(\mathbf{f},\mathbf{f_*}|\mathbf{y})$$</td>
        <td >$$d\mathbf{f}$$</td>
        <td >$$=$$</td>
        <td class="BayesMarg">$$1/p(\mathbf{y})$$</sub></td>
        <td >$$\int$$</td>
        <td class = "BayesLike">$$p(\mathbf{y}|\mathbf{f})$$</td>
        <td class = "BayesPrior">$$p(\mathbf{f},\mathbf{f_*})$$</td>
        <td >$$d\mathbf{f}$$</td>
    </tr>
</table>
''')
# Out:
# <script>
# $('.BayesPost').hover(
#   function(){
#         $('.BayesPost').css({"background":"white", "color":"blue"});
#   },function(){
#         $('.BayesPost').css({"background":"white", "color":"black"});
# });
# $('.PostPred').hover(
#   function(){
#         $('.PostPred').css({"background":"white", "color":"#00a6ff"});
#   },function(){
#         $('.PostPred').css({"background":"white", "color":"black"});
# });
# $('.a').hover(
#   function(){
#         $('.a').css({"background":"white", "color":"blue"});
#   },function(){
#         $('.a').css({"background":"white", "color":"black"});
# });
# $('.b').hover(
#   function(){
#         $('.b').css({"background":"white", "color":"green"});
#   },function(){
#         $('.b').css({"background":"white", "color":"black"});
# });
# $('.c').hover(
#   function(){
#         $('.c').css({"background":"white", "color":"#ab4d00"});
#   },function(){
#         $('.c').css({"background":"white", "color":"black"});
# });
# $('.d').hover(
# ...

# %% [markdown]
# Using the <span style="color:red">**Property of Gaussians**</span>

# %%
# @hidden
HTML('''
<script>
$('.PostPred').hover(
  function(){
        $('.PostPred').css({"background":"white", "color":"#00a6ff"});
  },function(){
        $('.PostPred').css({"background":"white", "color":"black"});
});
$('.a').hover(
  function(){
        $('.a').css({"background":"white", "color":"blue"});
  },function(){
        $('.a').css({"background":"white", "color":"black"});
});
$('.b').hover(
  function(){
        $('.b').css({"background":"white", "color":"green"});
  },function(){
        $('.b').css({"background":"white", "color":"black"});
});
$('.c').hover(
  function(){
        $('.c').css({"background":"white", "color":"#ab4d00"});
  },function(){
        $('.c').css({"background":"white", "color":"black"});
});
$('.d').hover(
  function(){
        $('.d').css({"background":"white", "color":"#00b8ae"});
  },function(){
        $('.d').css({"background":"white", "color":"black"});
});
$('.e').hover(
  function(){
        $('.e').css({"background":"#fcd4ff"});
  },function(){
        $('.e').css({"background":"white"});
});
$('.BayesLike').hover(
  function(){
        $('.BayesLike').css({"background":"white", "color":"#0cb500"});
  },function(){
        $('.BayesLike').css({"background":"white", "color":"black"});
});
</script>
<table style="margin-left: auto; margin-right: auto;">
    <tr style="background-color:white;font-size:16px">
        <td class = "PostPred">$$p(\mathbf{f_*}|\mathbf{y})$$</td>
        <td >$$=\mathcal{N}($$</td>
        <td class = "c">$$A$$</td>
        <td class = "BayesLike">$$C^{-1}$$</td>
        <td >$$\mathbf{f}$$</td>
        <td >,</td>
        <td class = "d">$$D$$</td>
        <td >$$-$$</td>
        <td class = "c">$$A$$</td>
        <td class = "BayesLike">$$C^{-1}$$</td>
        <td class = "b">$$A^T$$</td>
        <td >$$)$$</td>
    </tr>
</table>
''')
# Out:
# <script>
# $('.PostPred').hover(
#   function(){
#         $('.PostPred').css({"background":"white", "color":"#00a6ff"});
#   },function(){
#         $('.PostPred').css({"background":"white", "color":"black"});
# });
# $('.a').hover(
#   function(){
#         $('.a').css({"background":"white", "color":"blue"});
#   },function(){
#         $('.a').css({"background":"white", "color":"black"});
# });
# $('.b').hover(
#   function(){
#         $('.b').css({"background":"white", "color":"green"});
#   },function(){
#         $('.b').css({"background":"white", "color":"black"});
# });
# $('.c').hover(
#   function(){
#         $('.c').css({"background":"white", "color":"#ab4d00"});
#   },function(){
#         $('.c').css({"background":"white", "color":"black"});
# });
# $('.d').hover(
#   function(){
#         $('.d').css({"background":"white", "color":"#00b8ae"});
#   },function(){
#         $('.d').css({"background":"white", "color":"black"});
# });
# $('.e').hover(
#   function(){
# ...

# %% [markdown]
# **Limitations**

# %% [markdown]
# In the posterior predictive distribution, the time complexity of:

# %%
#@hidden
HTML('''
<script>
$('.BayesLike').hover(
  function(){
        $('.BayesLike').css({"background":"white", "color":"#0cb500"});
  },function(){
        $('.BayesLike').css({"background":"white", "color":"black"});
});
</script>
<table style="margin-left: auto; margin-right: auto;">
    <tr style="background-color:white;font-size:16px">
        <td class = "BayesLike">$$C^{-1}$$</td>
        <td >=</td>
        <td class = "BayesLike">$$(K(\mathbf{x},\mathbf{x}) + \sigma_n^2 I)^{-1}$$</td>
    </tr>
</table>
''')
# Out:
# <script>
# $('.BayesLike').hover(
#   function(){
#         $('.BayesLike').css({"background":"white", "color":"#0cb500"});
#   },function(){
#         $('.BayesLike').css({"background":"white", "color":"black"});
# });
# </script>
# <table style="margin-left: auto; margin-right: auto;">
#     <tr style="background-color:white;font-size:16px">
#         <td class = "BayesLike">$$C^{-1}$$</td>
#         <td >=</td>
#         <td class = "BayesLike">$$(K(\mathbf{x},\mathbf{x}) + \sigma_n^2 I)^{-1}$$</td>
#     </tr>
# </table>

# %% [markdown]
# <center>is  <span style="font-size:larger;">$\mathcal{O}(n^3)$</span>  !</center>

# %% [markdown]
# **Solution**

# %% [markdown]
# To reduce the computation complexity above, we approximate:

# %%
#@hidden
HTML('''
<script>
$('.BayesPrior').hover(
  function(){
        $('.BayesPrior').css({"background":"white", "color":"red"});
  },function(){
        $('.BayesPrior').css({"background":"white", "color":"black"});
});
</script>
<table style="margin-left: auto; margin-right: auto;">
    <tr style="background-color:white;font-size:16px">
        <td class = "BayesPrior">$$p(\mathbf{f},\mathbf{f_*})$$</td>
        <td >&#8776;</td>
        <td class = "BayesPrior">$$q(\mathbf{f},\mathbf{f_*})$$</td>
    </tr>
</table>
''')
# Out:
# <script>
# $('.BayesPrior').hover(
#   function(){
#         $('.BayesPrior').css({"background":"white", "color":"red"});
#   },function(){
#         $('.BayesPrior').css({"background":"white", "color":"black"});
# });
# </script>
# <table style="margin-left: auto; margin-right: auto;">
#     <tr style="background-color:white;font-size:16px">
#         <td class = "BayesPrior">$$p(\mathbf{f},\mathbf{f_*})$$</td>
#         <td >&#8776;</td>
#         <td class = "BayesPrior">$$q(\mathbf{f},\mathbf{f_*})$$</td>
#     </tr>
# </table>

# %% [markdown]
# But **how** do we approximate this?

# %% [markdown]
# <h1><u>A New Unifying view</u></h1>

# %% [markdown]
# <img width="75%" src="images/unifying_view.png">

# %% [markdown]
# With the consistency of GPs, we can recover the prior by marginalizing out the latent variable u from:

# %%
#@hidden
HTML('''
<script>
$('.BayesPrior').hover(
  function(){
        $('.BayesPrior').css({"background":"white", "color":"red"});
  },function(){
        $('.BayesPrior').css({"background":"white", "color":"black"});
});
$('.InducCond1').hover(
  function(){
        $('.InducCond1').css({"background":"white", "color":"#a600d4"});
  },function(){
        $('.InducCond1').css({"background":"white", "color":"black"});
});
$('.InducCond2').hover(
  function(){
        $('.InducCond2').css({"background":"white", "color":"#d40078"});
  },function(){
        $('.InducCond2').css({"background":"white", "color":"black"});
});
$('.LatPrior').hover(
  function(){
        $('.LatPrior').css({"background":"white", "color":"#7a6b04"});
  },function(){
        $('.LatPrior').css({"background":"white", "color":"black"});
});
</script>
<table style="margin-left: auto; margin-right: auto;">
    <tr style="background-color:white;font-size:16px">
        <td class = "BayesPrior">$$p(\mathbf{f},\mathbf{f_*})$$</td>
        <td >=</td>
        <td >$$\int$$</td>
        <td class = "InducCond1">$$p(\mathbf{f}|\mathbf{u})$$</td>
        <td class = "InducCond2">$$p(\mathbf{f_*}|\mathbf{u})$$</td>
        <td class = "LatPrior">$$p(\mathbf{u})$$</td>
        <td >$$d\mathbf{u}$$</td>
    </tr>
</table>
''')
# Out:
# <script>
# $('.BayesPrior').hover(
#   function(){
#         $('.BayesPrior').css({"background":"white", "color":"red"});
#   },function(){
#         $('.BayesPrior').css({"background":"white", "color":"black"});
# });
# $('.InducCond1').hover(
#   function(){
#         $('.InducCond1').css({"background":"white", "color":"#a600d4"});
#   },function(){
#         $('.InducCond1').css({"background":"white", "color":"black"});
# });
# $('.InducCond2').hover(
#   function(){
#         $('.InducCond2').css({"background":"white", "color":"#d40078"});
#   },function(){
#         $('.InducCond2').css({"background":"white", "color":"black"});
# });
# $('.LatPrior').hover(
#   function(){
#         $('.LatPrior').css({"background":"white", "color":"#7a6b04"});
#   },function(){
#         $('.LatPrior').css({"background":"white", "color":"black"});
# });
# </script>
# <table style="margin-left: auto; margin-right: auto;">
#     <tr style="background-color:white;font-size:16px">
# ...

# %% [markdown]
# **The Exact Inducing Conditionals** <br>
# We must now introduce the inducing conditionals which are approximated in the following efficient algorithms to retrieve the approximate $p(f,f_*) \thickapprox q(f,f_*)$:

# %%
#@hidden
HTML('''
<script>
$('.InducCond1').hover(
  function(){
        $('.InducCond1').css({"background":"white", "color":"#a600d4"});
  },function(){
        $('.InducCond1').css({"background":"white", "color":"black"});
});
$('.InducCond2').hover(
  function(){
        $('.InducCond2').css({"background":"white", "color":"#d40078"});
  },function(){
        $('.InducCond2').css({"background":"white", "color":"black"});
});
</script>
<table style="margin-left: auto; margin-right: auto;table-layout:fixed;font-size:16px">
    <tr style="background-color:white">
        <td class = "InducCond1">$$p(f|u)$$</td>
        <td >$$=$$</td>
        <td >$$\mathcal{N}(K_{f,u}K_{u,u}^{-1}u$$</td>
        <td >$$,K_{u,u}$$</td>
        <td >$$-$$</td>
        <td >$$K_{f,u}K_{u,u}^{-1}K_{u,f}$$</td>
        <td >$$)$$</td>
    </tr>
    <tr style="background-color:white">
        <td class = "InducCond2">$$p(f_*|u)$$</td>
        <td >$$=$$</td>
        <td >$$\mathcal{N}(K_{*,u}K_{u,u}^{-1}u$$</td>
        <td >$$,K_{u,u}$$</td>
        <td >$$-$$</td>
        <td >$$K_{*,u}K_{u,u}^{-1}K_{u,*}$$</td>
        <td >$$)$$</td>
    </tr>
</table>
''')
# Out:
# <script>
# $('.InducCond1').hover(
#   function(){
#         $('.InducCond1').css({"background":"white", "color":"#a600d4"});
#   },function(){
#         $('.InducCond1').css({"background":"white", "color":"black"});
# });
# $('.InducCond2').hover(
#   function(){
#         $('.InducCond2').css({"background":"white", "color":"#d40078"});
#   },function(){
#         $('.InducCond2').css({"background":"white", "color":"black"});
# });
# </script>
# <table style="margin-left: auto; margin-right: auto;table-layout:fixed;font-size:16px">
#     <tr style="background-color:white">
#         <td class = "InducCond1">$$p(f|u)$$</td>
#         <td >$$=$$</td>
#         <td >$$\mathcal{N}(K_{f,u}K_{u,u}^{-1}u$$</td>
#         <td >$$,K_{u,u}$$</td>
#         <td >$$-$$</td>
#         <td >$$K_{f,u}K_{u,u}^{-1}K_{u,f}$$</td>
#         <td >$$)$$</td>
#     </tr>
#     <tr style="background-color:white">
#         <td class = "InducCond2">$$p(f_*|u)$$</td>
#         <td >$$=$$</td>
# ...

# %% [markdown]
# **Approximate Inducing Conditionals** <br>
# By approximating the induction conditionals:

# %%
#@hidden
HTML('''
<script>
$('.InducCond1').hover(
  function(){
        $('.InducCond1').css({"background":"white", "color":"#a600d4"});
  },function(){
        $('.InducCond1').css({"background":"white", "color":"black"});
});
$('.InducCond2').hover(
  function(){
        $('.InducCond2').css({"background":"white", "color":"#d40078"});
  },function(){
        $('.InducCond2').css({"background":"white", "color":"black"});
});
</script>
<table style="margin-left: auto; margin-right: auto;table-layout:fixed;font-size:16px">
    <tr style="background-color:white">
        <td class = "InducCond1">$$p(f|u)$$</td>
        <td >$$&#8776;$$</td>
        <td class = "InducCond1">$$q(f|u)$$</td>
    </tr>
    <tr style="background-color:white">
        <td class = "InducCond2">$$p(f_*|u)$$</td>
        <td >$$&#8776;$$</td>
        <td class = "InducCond2">$$q(f_*|u)$$</td>
    </tr>
</table>
''')
# Out:
# <script>
# $('.InducCond1').hover(
#   function(){
#         $('.InducCond1').css({"background":"white", "color":"#a600d4"});
#   },function(){
#         $('.InducCond1').css({"background":"white", "color":"black"});
# });
# $('.InducCond2').hover(
#   function(){
#         $('.InducCond2').css({"background":"white", "color":"#d40078"});
#   },function(){
#         $('.InducCond2').css({"background":"white", "color":"black"});
# });
# </script>
# <table style="margin-left: auto; margin-right: auto;table-layout:fixed;font-size:16px">
#     <tr style="background-color:white">
#         <td class = "InducCond1">$$p(f|u)$$</td>
#         <td >$$&#8776;$$</td>
#         <td class = "InducCond1">$$q(f|u)$$</td>
#     </tr>
#     <tr style="background-color:white">
#         <td class = "InducCond2">$$p(f_*|u)$$</td>
#         <td >$$&#8776;$$</td>
#         <td class = "InducCond2">$$q(f_*|u)$$</td>
#     </tr>
# </table>

# %% [markdown]
# We can retrieve the approximate prior:

# %%
#@hidden
HTML('''
<script>
$('.BayesPrior').hover(
  function(){
        $('.BayesPrior').css({"background":"white", "color":"red"});
  },function(){
        $('.BayesPrior').css({"background":"white", "color":"black"});
});
$('.InducCond1').hover(
  function(){
        $('.InducCond1').css({"background":"white", "color":"#a600d4"});
  },function(){
        $('.InducCond1').css({"background":"white", "color":"black"});
});
$('.InducCond2').hover(
  function(){
        $('.InducCond2').css({"background":"white", "color":"#d40078"});
  },function(){
        $('.InducCond2').css({"background":"white", "color":"black"});
});
$('.LatPrior').hover(
  function(){
        $('.LatPrior').css({"background":"white", "color":"#7a6b04"});
  },function(){
        $('.LatPrior').css({"background":"white", "color":"black"});
});
</script>
<table style="margin-left: auto; margin-right: auto;">
    <tr style="background-color:white;font-size:16px">
        <td class = "BayesPrior">$$p(f,f_*)$$</td>
        <td >&#8776;</td>
        <td class = "BayesPrior">$$q(f,f_*)$$</td>
        <td >=</td>
        <td >$$\int$$</td>
        <td class = "InducCond1">$$q(f|u)$$</td>
        <td class = "InducCond2">$$q(f_*|u)$$</td>
        <td class = "LatPrior">$$p(u)$$</td>
        <td >$$du$$</td>
    </tr>
</table>
''')
# Out:
# <script>
# $('.BayesPrior').hover(
#   function(){
#         $('.BayesPrior').css({"background":"white", "color":"red"});
#   },function(){
#         $('.BayesPrior').css({"background":"white", "color":"black"});
# });
# $('.InducCond1').hover(
#   function(){
#         $('.InducCond1').css({"background":"white", "color":"#a600d4"});
#   },function(){
#         $('.InducCond1').css({"background":"white", "color":"black"});
# });
# $('.InducCond2').hover(
#   function(){
#         $('.InducCond2').css({"background":"white", "color":"#d40078"});
#   },function(){
#         $('.InducCond2').css({"background":"white", "color":"black"});
# });
# $('.LatPrior').hover(
#   function(){
#         $('.LatPrior').css({"background":"white", "color":"#7a6b04"});
#   },function(){
#         $('.LatPrior').css({"background":"white", "color":"black"});
# });
# </script>
# <table style="margin-left: auto; margin-right: auto;">
#     <tr style="background-color:white;font-size:16px">
# ...

# %%
#@hidden
HTML('''
Note that:
<table style="margin-left: auto; margin-right: auto;table-layout:fixed;font-size:16px">
    <tr style="background-color:white">
        <td >$$Q_{a,b}$$</td>
        <td >$$&#x225D;$$</td>
        <td >$$K_{a,u}K_{u,u}^{-1}K_{u,b}$$</td>
    </tr>
</table>
''')
# Out:
# Note that:
# <table style="margin-left: auto; margin-right: auto;table-layout:fixed;font-size:16px">
#     <tr style="background-color:white">
#         <td >$$Q_{a,b}$$</td>
#         <td >$$&#x225D;$$</td>
#         <td >$$K_{a,u}K_{u,u}^{-1}K_{u,b}$$</td>
#     </tr>
# </table>

# %% [markdown]
# <h1><u>Approximation methods</u></h1>

# %% [markdown]
# <h3><u>Subset of Regressors (SoR) Approximation</u></h3>

# %% [markdown]
# <img width="25%" src="images/SoR_graph_model.png">

# %%
#@hidden
HTML('''
<script>
$('.a').hover(
  function(){
        $('.a').css({"background":"blue", "color":"white"});
  },function(){
        $('.a').css({"background":"white", "color":"black"});
});
$('.b').hover(
  function(){
        $('.b').css({"background":"green", "color":"white"});
  },function(){
        $('.b').css({"background":"white", "color":"black"});
});
$('.c').hover(
  function(){
        $('.c').css({"background":"red", "color":"white"});
  },function(){
        $('.c').css({"background":"white", "color":"black"});
});
$('.d').hover(
  function(){
        $('.d').css({"background":"yellow"});
  },function(){
        $('.d').css({"background":"white"});
});
$('.InducCond1').hover(
  function(){
        $('.InducCond1').css({"background":"white", "color":"#a600d4"});
  },function(){
        $('.InducCond1').css({"background":"white", "color":"black"});
});
$('.InducCond2').hover(
  function(){
        $('.InducCond2').css({"background":"white", "color":"#d40078"});
  },function(){
        $('.InducCond2').css({"background":"white", "color":"black"});
});
$('.LatPrior').hover(
  function(){
        $('.LatPrior').css({"background":"white", "color":"#7a6b04"});
  },function(){
        $('.LatPrior').css({"background":"white", "color":"black"});
});
$('.BayesPrior').hover(
  function(){
        $('.BayesPrior').css({"background":"white", "color":"red"});
  },function(){
        $('.BayesPrior').css({"background":"white", "color":"black"});
});
$('.BayesLike').hover(
  function(){
        $('.BayesLike').css({"background":"white", "color":"#0cb500"});
  },function(){
        $('.BayesLike').css({"background":"white", "color":"black"});
});
$('.PostPred').hover(
  function(){
        $('.PostPred').css({"background":"white", "color":"#00a6ff"});
  },function(){
        $('.PostPred').css({"background":"white", "color":"black"});
});
</script>
Key assumptions: <br>
<br>
1. The relationship between $f$ and $u$ is deterministic
<table style="margin-left: auto; margin-right: auto;table-layout:fixed;font-size:16px">
    <tr style="background-color:white">
        <td >$$f$$</td>
        <td >$$=$$</td>
        <td >$$K_{f,u}K_{u,u}^{-1}u$$</td>
    </tr>
</table>
2. The relationship between $f_*$ and $u$ is deterministic
<table style="margin-left: auto; margin-right: auto;table-layout:fixed;font-size:16px">
    <tr style="background-color:white">
        <td >$$f_*$$</td>
        <td >$$=$$</td>
        <td >$$K_{*,u}K_{u,u}^{-1}u$$</td>
    </tr>
</table>
<br>
Where
<table style="margin-left: auto; margin-right: auto;">
    <tr style="background-color:white;font-size:16px">
        <td class = "LatPrior">$$u \sim \mathcal{N}(0,K_{u,u})$$</td>
    </tr>
</table>
This implies that the approximate inducing conditionals are:
<table style="margin-left: auto; margin-right: auto;table-layout:fixed;font-size:16px">
    <tr style="background-color:white">
        <td class = "InducCond1">$$q_{SoR}(f|u)$$</td>
        <td >$$=$$</td>
        <td >$$\mathcal{N}(K_{f,u}K_{u,u}^{-1}u$$</td>
        <td >$$,$$</td>
        <td >$$0)$$</td>
    </tr>
    <tr style="background-color:white">
        <td class = "InducCond2">$$q_{SoR}(f_*|u)$$</td>
        <td >$$=$$</td>
        <td >$$\mathcal{N}(K_{*,u}K_{u,u}^{-1}u$$</td>
        <td >$$,$$</td>
        <td >$$0)$$</td>
    </tr>
</table>
Therefore, the inducing prior is given by:
<table style="margin-left: auto; margin-right: auto;">
    <tr>
        <th colspan="11" style="text-align: center;">SoR (Noiseless)</th>
    </tr>
    <tr style="background-color:white;">
        <td rowspan = 2 class = "BayesPrior" >$$\Bigg[ \matrix{ f \cr f_*} \Bigg]$$</td>
        <td rowspan = 2 >$$\sim N \Bigg($$</td>
        <td rowspan = 2 >$$\Bigg[$$</td>
        <td >$$0$$</td>
        <td rowspan = 2 >$$\Bigg]$$</td>
        <td rowspan = 2 style="font-size:15px">,</td>
        <td rowspan = 2 >$$\Bigg[$$</td>
        <td class = "a" >$$Q_{f,f}$$</td>
        <td class = "b" >$$Q_{f,*}$$</td>
        <td rowspan = 2 >$$\Bigg]$$</td>
        <td rowspan = 2 >$$\Bigg)$$</td>
    </tr>
    <tr style="background-color:white;">
        <td >$$0$$</td>
        <td class = "c" >$$Q_{*,f}$$</td>
        <td class = "d" >$$Q_{*,*}$$</td>
    </tr>
</table>
With the exact likelihood $p(y|f)$
<table style="margin-left: auto; margin-right: auto;">
    <tr>
        <th colspan="11" style="text-align: center;">SoR (Noisy)</th>
    </tr>
    <tr style="background-color:white;">
        <td rowspan = 2 class = "BayesPrior" >$$\Bigg[ \matrix{ y \cr f_*} \Bigg]$$</td>
        <td rowspan = 2 >$$\sim N \Bigg($$</td>
        <td rowspan = 2 >$$\Bigg[$$</td>
        <td >$$0$$</td>
        <td rowspan = 2 >$$\Bigg]$$</td>
        <td rowspan = 2 style="font-size:15px">,</td>
        <td rowspan = 2 >$$\Bigg[$$</td>
        <td class = "BayesLike" >$$Q_{f,f} + \sigma_n^2 I$$</td>
        <td class = "b" >$$Q_{f,*}$$</td>
        <td rowspan = 2 >$$\Bigg]$$</td>
        <td rowspan = 2 >$$\Bigg)$$</td>
    </tr>
    <tr style="background-color:white;">
        <td >$$0$$</td>
        <td class = "c" >$$Q_{*,f}$$</td>
        <td class = "d" >$$Q_{*,*}$$</td>
    </tr>
</table>
Using the Property of Gaussians, the posterior predictive distribution is:
<table style="margin-left: auto; margin-right: auto;">
    <tr style="background-color:white;table-layout:fixed;font-size:16px">
        <td class = "PostPred">$$q_{SoR}(f_*|y)$$</td>
        <td >$$=N($$</td>
        <td class = "c">$$Q_{*,f}$$</td>
        <td class = "BayesLike" style="width:10px">$$(Q_{f,f} + \sigma_n^2 I)^{-1}$$</td>
        <td >$$y$$</td>
        <td >,</td>
        <td class = "d">$$Q_{*,*}$$</td>
        <td >$$-$$</td>
        <td class = "c">$$Q_{*,f}$$</td>
        <td class = "BayesLike" style="width:10px">$$(Q_{f,f} + \sigma_n^2 I)^{-1}$$</td>
        <td class = "b">$$Q_{f,*}$$</td>
        <td >$$)$$</td>
    </tr>
</table>
A computationally efficient representation of the posterior predictive prediction is:
<table style="margin-left: auto; table-layout:fixed; margin-right: auto;">
    <tr style="background-color:white;table-layout:fixed;font-size:16px">
        <td class = "PostPred">$$q_{SoR}(f_*|y)$$</td>
        <td >$$=\mathcal{N}($$</td>
        <td style="width:10px">$$\sigma_n^{-2} K_{*,u} \Sigma K_{u,f} y$$</td>
        <td >,</td>
        <td style="width:10px">$$K_{*,u} \Sigma K_{u,*}$$</td>
        <td >$$)$$</td>
    </tr>
</table>
Where $$\Sigma = (\sigma_n^{-2} K_{u,f} K_{f,u} + K_{u,u})^{-1}$$
''')
# Out:
# <script>
# $('.a').hover(
#   function(){
#         $('.a').css({"background":"blue", "color":"white"});
#   },function(){
#         $('.a').css({"background":"white", "color":"black"});
# });
# $('.b').hover(
#   function(){
#         $('.b').css({"background":"green", "color":"white"});
#   },function(){
#         $('.b').css({"background":"white", "color":"black"});
# });
# $('.c').hover(
#   function(){
#         $('.c').css({"background":"red", "color":"white"});
#   },function(){
#         $('.c').css({"background":"white", "color":"black"});
# });
# $('.d').hover(
#   function(){
#         $('.d').css({"background":"yellow"});
#   },function(){
#         $('.d').css({"background":"white"});
# });
# $('.InducCond1').hover(
#   function(){
#         $('.InducCond1').css({"background":"white", "color":"#a600d4"});
#   },function(){
#         $('.InducCond1').css({"background":"white", "color":"black"});
# });
# $('.InducCond2').hover(
#   function(){
# ...

# %%
#@hidden
HTML('''<script>
function toggle_next(event) {
    $(event.target).closest('div.code_cell').next().find('div.output').toggle();
}
</script>
<b>To toggle on/off the details of how we arrive at the inducing prior <a onclick="toggle_next(event)">here</a>.</b>''')
# Out:
# <script>
# function toggle_next(event) {
#     $(event.target).closest('div.code_cell').next().find('div.output').toggle();
# }
# </script>
# <b>To toggle on/off the details of how we arrive at the inducing prior <a onclick="toggle_next(event)">here</a>.</b>

# %%
#@hidden
HTML('''
How do we arrive at the inducing prior? <br>
Recall that we arrive at the inducing prior through the following:
<table style="margin-left: auto; margin-right: auto;">
    <tr style="background-color:white;font-size:16px">
        <td class = "BayesPrior">$$p(f,f_*)$$</td>
        <td >&#8776;</td>
        <td class = "BayesPrior">$$q(f,f_*)$$</td>
        <td >=</td>
        <td >$$\int$$</td>
        <td class = "InducCond1">$$q(f|u)$$</td>
        <td class = "InducCond2">$$q(f_*|u)$$</td>
        <td class = "LatPrior">$$p(u)$$</td>
        <td >$$du$$</td>
    </tr>
</table>
As the inducing points and the inducing conditionals are normally distributed, the inducing prior is also normally distributed. With the deterministic inducing conditional assumption, we know that:
<table style="margin-left: auto; margin-right: auto;table-layout:fixed;font-size:16px">
    <tr style="background-color:white">
        <td >$$\mathbb{E}_u[f]$$</td>
        <td >$$=$$</td>
        <td >$$0$$</td>
    </tr>
    <tr style="background-color:white">
        <td >$$\mathbb{E}_u[f_*]$$</td>
        <td >$$=$$</td>
        <td >$$0$$</td>
    </tr>
</table>
Part of the covariance can be found by:
<table style="margin-left: auto; margin-right: auto;table-layout:fixed;font-size:16px">
    <tr style="background-color:white">
        <td >$$cov(f,f_*)$$</td>
        <td >$$=$$</td>
        <td >$$\mathbb{E}_u[ff_*]$$</td>
        <td >$$-$$</td>
        <td >$$\mathbb{E}_u[f]\;\mathbb{E}_u[f_*]$$</td>
    </tr>
    <tr style="background-color:white">
        <td ></td>
        <td >$$=$$</td>
        <td colspan=3>$$\mathbb{E}_u[ff_*]$$</td>
    </tr>
    <tr style="background-color:white">
        <td ></td>
        <td >$$=$$</td>
        <td colspan=3>$$\mathbb{E}_u[K_{f,u} K_{u,u}^{-1} u u^T K_{u,u}^{-1} K_{u,*}]$$</td>
    </tr>
    <tr style="background-color:white">
        <td ></td>
        <td >$$=$$</td>
        <td colspan=3>$$K_{f,u} K_{u,u}^{-1} \; \mathbb{E}_u[u u^T] \; K_{u,u}^{-1} K_{u,*}$$</td>
    </tr>
    <tr style="background-color:white">
        <td ></td>
        <td >$$=$$</td>
        <td colspan=3>$$K_{f,u} K_{u,u}^{-1} \; var(u) \; K_{u,u}^{-1} K_{u,*}$$</td>
    </tr>
    <tr style="background-color:white">
        <td ></td>
        <td >$$=$$</td>
        <td colspan=3>$$K_{f,u} K_{u,u}^{-1} K_{u,u} K_{u,u}^{-1} K_{u,*}$$</td>
    </tr>
    <tr style="background-color:white">
        <td ></td>
        <td >$$=$$</td>
        <td colspan=3>$$K_{f,u} K_{u,u}^{-1} K_{u,*}$$</td>
    </tr>
    <tr style="background-color:white">
        <td ></td>
        <td >$$=$$</td>
        <td colspan=3>$$Q_{f,*}$$</td>
    </tr>
</table>
''')
# Out:
# How do we arrive at the inducing prior? <br>
# Recall that we arrive at the inducing prior through the following:
# <table style="margin-left: auto; margin-right: auto;">
#     <tr style="background-color:white;font-size:16px">
#         <td class = "BayesPrior">$$p(f,f_*)$$</td>
#         <td >&#8776;</td>
#         <td class = "BayesPrior">$$q(f,f_*)$$</td>
#         <td >=</td>
#         <td >$$\int$$</td>
#         <td class = "InducCond1">$$q(f|u)$$</td>
#         <td class = "InducCond2">$$q(f_*|u)$$</td>
#         <td class = "LatPrior">$$p(u)$$</td>
#         <td >$$du$$</td>
#     </tr>
# </table>
# As the inducing points and the inducing conditionals are normally distributed, the inducing prior is also normally distributed. With the deterministic inducing conditional assumption, we know that:
# <table style="margin-left: auto; margin-right: auto;table-layout:fixed;font-size:16px">
#     <tr style="background-color:white">
#         <td >$$\mathbb{E}_u[f]$$</td>
# ...

# %% [markdown]
# Limitations: <br>
# Unreasonable predictive uncertainties for points $x_*$ that is far away from inducing inputs in $x_u$

# %% [markdown]
# <h3><u>Deterministic Training Conditional (DTC) Approximation</u></h3>

# %% [markdown]
# <img width="25%" src="images/DTC_graph_model.png">

# %%
#@hidden
HTML('''
<script>
$('.a').hover(
  function(){
        $('.a').css({"background":"white", "color":"blue"});
  },function(){
        $('.a').css({"background":"white", "color":"black"});
});
$('.b').hover(
  function(){
        $('.b').css({"background":"white", "color":"green"});
  },function(){
        $('.b').css({"background":"white", "color":"black"});
});
$('.c').hover(
  function(){
        $('.c').css({"background":"white", "color":"#ab4d00"});
  },function(){
        $('.c').css({"background":"white", "color":"black"});
});
$('.d').hover(
  function(){
        $('.d').css({"background":"white", "color":"#00b8ae"});
  },function(){
        $('.d').css({"background":"white", "color":"black"});
});
$('.InducCond1').hover(
  function(){
        $('.InducCond1').css({"background":"white", "color":"#a600d4"});
  },function(){
        $('.InducCond1').css({"background":"white", "color":"black"});
});
$('.InducCond2').hover(
  function(){
        $('.InducCond2').css({"background":"white", "color":"#d40078"});
  },function(){
        $('.InducCond2').css({"background":"white", "color":"black"});
});
$('.LatPrior').hover(
  function(){
        $('.LatPrior').css({"background":"white", "color":"#7a6b04"});
  },function(){
        $('.LatPrior').css({"background":"white", "color":"black"});
});
$('.BayesPrior').hover(
  function(){
        $('.BayesPrior').css({"background":"white", "color":"red"});
  },function(){
        $('.BayesPrior').css({"background":"white", "color":"black"});
});
$('.BayesLike').hover(
  function(){
        $('.BayesLike').css({"background":"white", "color":"#0cb500"});
  },function(){
        $('.BayesLike').css({"background":"white", "color":"black"});
});
$('.PostPred').hover(
  function(){
        $('.PostPred').css({"background":"white", "color":"#00a6ff"});
  },function(){
        $('.PostPred').css({"background":"white", "color":"black"});
});
</script>
Key assumptions: <br>
<br>
1. The relationship between $f$ and $u$ is deterministic
<table style="margin-left: auto; margin-right: auto;table-layout:fixed;font-size:16px">
    <tr style="background-color:white">
        <td >$$f$$</td>
        <td >$$=$$</td>
        <td >$$K_{f,u}K_{u,u}^{-1}u$$</td>
    </tr>
</table>
2. The relationship between $f*$ and $u$ is exact
<br>
<br>
Where
<table style="margin-left: auto; margin-right: auto;">
    <tr style="background-color:white;font-size:16px">
        <td class = "LatPrior">$$u \sim \mathcal{N}(0,K_{u,u})$$</td>
    </tr>
</table>
This implies that the approximate inducing conditionals are:
<table style="margin-left: auto; margin-right: auto;table-layout:fixed;font-size:16px">
    <tr style="background-color:white">
        <td class = "InducCond1">$$q_{DTC}(f|u)$$</td>
        <td >$$=$$</td>
        <td >$$\mathcal{N}(K_{f,u}K_{u,u}^{-1}u$$</td>
        <td >$$,$$</td>
        <td >$$0)$$</td>
    </tr>
</table>
<table style="margin-left: auto; margin-right: auto;table-layout:fixed;font-size:16px">
    <tr style="background-color:white">
        <td class = "InducCond2" style="width:100px">$$q_{DTC}(f_*|u)$$</td>
        <td >$$=$$</td>
        <td class = "InducCond2" style="width:70px">$$p(f_*|u)$$</td>
        <td >$$=$$</td>
        <td >$$\mathcal{N}($$</td>
        <td style="width:50px">$$K_{*,u}K_{u,u}^{-1}u$$</td>
        <td >$$,$$</td>
        <td >$$K_{u,u}$$</td>
        <td >$$-$$</td>
        <td >$$Q_{*,*}$$</td>
        <td >$$)$$</td>
    </tr>
</table>
Therefore, the inducing prior is given by:
<table style="margin-left: auto; margin-right: auto;">
    <tr>
        <th colspan="11" style="text-align: center;">DTC (Noiseless)</th>
    </tr>
    <tr style="background-color:white;">
        <td rowspan = 2 class = "BayesPrior" >$$\Bigg[ \matrix{ f \cr f_*} \Bigg]$$</td>
        <td rowspan = 2 >$$\sim N \Bigg($$</td>
        <td rowspan = 2 >$$\Bigg[$$</td>
        <td >$$0$$</td>
        <td rowspan = 2 >$$\Bigg]$$</td>
        <td rowspan = 2 style="font-size:15px">,</td>
        <td rowspan = 2 >$$\Bigg[$$</td>
        <td class = "a" >$$Q_{f,f}$$</td>
        <td class = "b" >$$Q_{f,*}$$</td>
        <td rowspan = 2 >$$\Bigg]$$</td>
        <td rowspan = 2 >$$\Bigg)$$</td>
    </tr>
    <tr style="background-color:white;">
        <td >$$0$$</td>
        <td class = "c" >$$Q_{*,f}$$</td>
        <td class = "d" >$$K_{*,*}$$</td>
    </tr>
</table>
With the exact likelihood $p(y|f)$
<table style="margin-left: auto; margin-right: auto;">
    <tr>
        <th colspan="11" style="text-align: center;">DTC (Noisy)</th>
    </tr>
    <tr style="background-color:white;">
        <td rowspan = 2 class = "BayesPrior" >$$\Bigg[ \matrix{ y \cr f_*} \Bigg]$$</td>
        <td rowspan = 2 >$$\sim N \Bigg($$</td>
        <td rowspan = 2 >$$\Bigg[$$</td>
        <td >$$0$$</td>
        <td rowspan = 2 >$$\Bigg]$$</td>
        <td rowspan = 2 style="font-size:15px">,</td>
        <td rowspan = 2 >$$\Bigg[$$</td>
        <td class = "BayesLike" >$$Q_{f,f} + \sigma_n^2 I$$</td>
        <td class = "b" >$$Q_{f,*}$$</td>
        <td rowspan = 2 >$$\Bigg]$$</td>
        <td rowspan = 2 >$$\Bigg)$$</td>
    </tr>
    <tr style="background-color:white;">
        <td >$$0$$</td>
        <td class = "c" >$$Q_{*,f}$$</td>
        <td class = "d" >$$K_{*,*}$$</td>
    </tr>
</table>
Using the Property of Gaussians, the posterior predictive distribution is:
<table style="margin-left: auto; margin-right: auto;">
    <tr style="background-color:white;table-layout:fixed;font-size:16px">
        <td class = "PostPred" style="width:100px">$$q_{DTC}(f_*|y)$$</td>
        <td >$$=N($$</td>
        <td class = "c">$$Q_{*,f}$$</td>
        <td class = "BayesLike" style="width:10px">$$(Q_{f,f} + \sigma_n^2 I)^{-1}$$</td>
        <td >$$y$$</td>
        <td >,</td>
        <td class = "d">$$K_{*,*}$$</td>
        <td >$$-$$</td>
        <td class = "c">$$Q_{*,f}$$</td>
        <td class = "BayesLike" style="width:10px">$$(Q_{f,f} + \sigma_n^2 I)^{-1}$$</td>
        <td class = "b">$$Q_{f,*}$$</td>
        <td >$$)$$</td>
    </tr>
</table>
A computationally efficient representation of the posterior predictive prediction is:
<table style="margin-left: auto; table-layout:fixed; margin-right: auto;">
    <tr style="background-color:white;table-layout:fixed;font-size:16px">
        <td class = "PostPred">$$q_{DTC}(f_*|y)$$</td>
        <td >$$=\mathcal{N}($$</td>
        <td style="width:10px">$$\sigma_n^{-2} K_{*,u} \Sigma K_{u,f} y$$</td>
        <td >,</td>
        <td style="width:10px">$$K_{*,*} - Q_{*,*} + K_{*,u} \Sigma K_{u,*}$$</td>
        <td >$$)$$</td>
    </tr>
</table>
Where $$\Sigma = (\sigma_n^{-2} K_{u,f} K_{f,u} + K_{u,u})^{-1}$$
''')
# Out:
# <script>
# $('.a').hover(
#   function(){
#         $('.a').css({"background":"white", "color":"blue"});
#   },function(){
#         $('.a').css({"background":"white", "color":"black"});
# });
# $('.b').hover(
#   function(){
#         $('.b').css({"background":"white", "color":"green"});
#   },function(){
#         $('.b').css({"background":"white", "color":"black"});
# });
# $('.c').hover(
#   function(){
#         $('.c').css({"background":"white", "color":"#ab4d00"});
#   },function(){
#         $('.c').css({"background":"white", "color":"black"});
# });
# $('.d').hover(
#   function(){
#         $('.d').css({"background":"white", "color":"#00b8ae"});
#   },function(){
#         $('.d').css({"background":"white", "color":"black"});
# });
# $('.InducCond1').hover(
#   function(){
#         $('.InducCond1').css({"background":"white", "color":"#a600d4"});
#   },function(){
#         $('.InducCond1').css({"background":"white", "color":"black"});
# });
# $('.InducCond2').hover(
# ...

# %% [markdown]
# Note: <br>
# Despite solving the unreasonable predictive uncertainties from SoR, DTC does not correspond to a GP.

# %% [markdown]
# <h3><u>Fully Independent Training Conditional (FITC) Approximation</u></h3>

# %% [markdown]
# <img width="30%" src="images/FITC_graph_model.png">

# %%
#@hidden
HTML('''
<script>
$('.a').hover(
  function(){
        $('.a').css({"background":"white", "color":"blue"});
  },function(){
        $('.a').css({"background":"white", "color":"black"});
});
$('.b').hover(
  function(){
        $('.b').css({"background":"white", "color":"green"});
  },function(){
        $('.b').css({"background":"white", "color":"black"});
});
$('.c').hover(
  function(){
        $('.c').css({"background":"white", "color":"#ab4d00"});
  },function(){
        $('.c').css({"background":"white", "color":"black"});
});
$('.d').hover(
  function(){
        $('.d').css({"background":"white", "color":"#00b8ae"});
  },function(){
        $('.d').css({"background":"white", "color":"black"});
});
$('.InducCond1').hover(
  function(){
        $('.InducCond1').css({"background":"white", "color":"#a600d4"});
  },function(){
        $('.InducCond1').css({"background":"white", "color":"black"});
});
$('.InducCond2').hover(
  function(){
        $('.InducCond2').css({"background":"white", "color":"#d40078"});
  },function(){
        $('.InducCond2').css({"background":"white", "color":"black"});
});
$('.LatPrior').hover(
  function(){
        $('.LatPrior').css({"background":"white", "color":"#7a6b04"});
  },function(){
        $('.LatPrior').css({"background":"white", "color":"black"});
});
$('.BayesPrior').hover(
  function(){
        $('.BayesPrior').css({"background":"white", "color":"red"});
  },function(){
        $('.BayesPrior').css({"background":"white", "color":"black"});
});
$('.BayesLike').hover(
  function(){
        $('.BayesLike').css({"background":"white", "color":"#0cb500"});
  },function(){
        $('.BayesLike').css({"background":"white", "color":"black"});
});
$('.PostPred').hover(
  function(){
        $('.PostPred').css({"background":"white", "color":"#00a6ff"});
  },function(){
        $('.PostPred').css({"background":"white", "color":"black"});
});
</script>
Key assumptions: <br>
<br>
1. The relationship between $f$ and $u$ is fully independent. <br>
2. The relationship between $f*$ and $u$ is exact.<br>
<br>
Where
<table style="margin-left: auto; margin-right: auto;">
    <tr style="background-color:white;font-size:16px">
        <td class = "LatPrior">$$u \sim \mathcal{N}(0,K_{u,u})$$</td>
    </tr>
</table>
This implies that the approximate inducing conditionals are:
<table style="margin-left: auto; margin-right: auto;table-layout:fixed;font-size:16px">
    <tr style="background-color:white">
        <td class = "InducCond1">$$q_{FITC}(f|u)$$</td>
        <td >$$=$$</td>
        <td >$$\prod_{i=1}^n p(f_i|u)$$</td>
        <td >$$=$$</td>
        <td style="width:110px">$$\mathcal{N}(K_{f,u}K_{u,u}^{-1}u$$</td>
        <td >$$,$$</td>
        <td style="width:160px">$$diag[K_{f,f} - Q_{f,f}]$$</td>
        <td >$$)$$</td>
    </tr>
</table>
<table style="margin-left: auto; margin-right: auto;table-layout:fixed;font-size:16px">
    <tr style="background-color:white">
        <td class = "InducCond2" style="width:110px">$$q_{FITC}(f_*|u)$$</td>
        <td >$$=$$</td>
        <td class = "InducCond2" style="width:70px">$$p(f_*|u)$$</td>
        <td >$$=$$</td>
        <td >$$\mathcal{N}($$</td>
        <td style="width:50px">$$K_{*,u}K_{u,u}^{-1}u$$</td>
        <td >$$,$$</td>
        <td >$$K_{u,u}$$</td>
        <td >$$-$$</td>
        <td >$$Q_{*,*}$$</td>
        <td >$$)$$</td>
    </tr>
</table>
Therefore, the inducing prior is given by:
<table style="margin-left: auto; margin-right: auto;table-layout:fixed;">
    <tr>
        <th colspan="11" style="text-align: center;">FITC (Noiseless)</th>
    </tr>
    <tr style="background-color:white;">
        <td rowspan = 2 class = "BayesPrior" >$$\Bigg[ \matrix{ f \cr f_*} \Bigg]$$</td>
        <td rowspan = 2 >$$\sim N \Bigg($$</td>
        <td rowspan = 2 >$$\Bigg[$$</td>
        <td >$$0$$</td>
        <td rowspan = 2 >$$\Bigg]$$</td>
        <td rowspan = 2 style="font-size:15px">,</td>
        <td rowspan = 2 >$$\Bigg[$$</td>
        <td class = "a" style="width:190px">$$Q_{f,f} - diag[Q_{f,f} - K_{f,f}]$$</td>
        <td class = "b" >$$Q_{f,*}$$</td>
        <td rowspan = 2 >$$\Bigg]$$</td>
        <td rowspan = 2 >$$\Bigg)$$</td>
    </tr>
    <tr style="background-color:white;">
        <td >$$0$$</td>
        <td class = "c" >$$Q_{*,f}$$</td>
        <td class = "d" >$$K_{*,*}$$</td>
    </tr>
</table>
With the exact likelihood $p(y|f)$
<table style="margin-left: auto; margin-right: auto;table-layout:fixed;">
    <tr>
        <th colspan="11" style="text-align: center;">FITC (Noisy)</th>
    </tr>
    <tr style="background-color:white;">
        <td rowspan = 2 class = "BayesPrior" >$$\Bigg[ \matrix{ y \cr f_*} \Bigg]$$</td>
        <td rowspan = 2 >$$\sim N \Bigg($$</td>
        <td rowspan = 2 >$$\Bigg[$$</td>
        <td >$$0$$</td>
        <td rowspan = 2 >$$\Bigg]$$</td>
        <td rowspan = 2 style="font-size:15px">,</td>
        <td rowspan = 2 >$$\Bigg[$$</td>
        <td class = "BayesLike" >$$Q_{f,f} + \Lambda $$</td>
        <td class = "b" >$$Q_{f,*}$$</td>
        <td rowspan = 2 >$$\Bigg]$$</td>
        <td rowspan = 2 >$$\Bigg)$$</td>
    </tr>
    <tr style="background-color:white;">
        <td >$$0$$</td>
        <td class = "c" >$$Q_{*,f}$$</td>
        <td class = "d" >$$K_{*,*}$$</td>
    </tr>
</table>
Where $$\Lambda = diag[K_{f,f} - Q_{f,f} + \sigma_n^2 I]$$<br>
Using the Property of Gaussians, the posterior predictive distribution is:
<table style="margin-left: auto; margin-right: auto;">
    <tr style="background-color:white;table-layout:fixed;font-size:16px">
        <td class = "PostPred" style="width:110px">$$q_{FITC}(f_*|y)$$</td>
        <td >$$=N($$</td>
        <td class = "c">$$Q_{*,f}$$</td>
        <td class = "BayesLike" style="width:10px">$$(Q_{f,f} + \Lambda)^{-1}$$</td>
        <td >$$y$$</td>
        <td >,</td>
        <td class = "d">$$K_{*,*}$$</td>
        <td >$$-$$</td>
        <td class = "c">$$Q_{*,f}$$</td>
        <td class = "BayesLike" style="width:10px">$$(Q_{f,f} + \Lambda)^{-1}$$</td>
        <td class = "b">$$Q_{f,*}$$</td>
        <td >$$)$$</td>
    </tr>
</table>
A computationally efficient representation of the posterior predictive prediction is:
<table style="margin-left: auto; table-layout:fixed; margin-right: auto;">
    <tr style="background-color:white;table-layout:fixed;font-size:16px">
        <td class = "PostPred">$$q_{FITC}(f_*|y)$$</td>
        <td >$$=\mathcal{N}($$</td>
        <td style="width:10px">$$\sigma_n^{-2} K_{*,u} \Sigma K_{u,f} \Lambda^{-1} y$$</td>
        <td >,</td>
        <td style="width:10px">$$K_{*,*} - Q_{*,*} + K_{*,u} \Sigma K_{u,*}$$</td>
        <td >$$)$$</td>
    </tr>
</table>
Where $$\Sigma = (K_{u,u} + K_{u,f}\Lambda^{-1}K_{f,u})^{-1}$$
''')
# Out:
# <script>
# $('.a').hover(
#   function(){
#         $('.a').css({"background":"white", "color":"blue"});
#   },function(){
#         $('.a').css({"background":"white", "color":"black"});
# });
# $('.b').hover(
#   function(){
#         $('.b').css({"background":"white", "color":"green"});
#   },function(){
#         $('.b').css({"background":"white", "color":"black"});
# });
# $('.c').hover(
#   function(){
#         $('.c').css({"background":"white", "color":"#ab4d00"});
#   },function(){
#         $('.c').css({"background":"white", "color":"black"});
# });
# $('.d').hover(
#   function(){
#         $('.d').css({"background":"white", "color":"#00b8ae"});
#   },function(){
#         $('.d').css({"background":"white", "color":"black"});
# });
# $('.InducCond1').hover(
#   function(){
#         $('.InducCond1').css({"background":"white", "color":"#a600d4"});
#   },function(){
#         $('.InducCond1').css({"background":"white", "color":"black"});
# });
# $('.InducCond2').hover(
# ...

# %% [markdown]
# Note: <br>
# The independence assumption can be extended to the test inducing conditional $q(f_*|u)$. In doing so, FITC becomes FIC. FITC is does not correspond to a GP but FIC does.

# %% [markdown]
# <h3><u>Partially Independent Training Conditional (PITC) Approximation</u></h3>

# %% [markdown]
# <img width="40%" src="images/PITC_graph_model.png">

# %%
#@hidden
HTML('''
<script>
$('.a').hover(
  function(){
        $('.a').css({"background":"white", "color":"blue"});
  },function(){
        $('.a').css({"background":"white", "color":"black"});
});
$('.b').hover(
  function(){
        $('.b').css({"background":"white", "color":"green"});
  },function(){
        $('.b').css({"background":"white", "color":"black"});
});
$('.c').hover(
  function(){
        $('.c').css({"background":"white", "color":"#ab4d00"});
  },function(){
        $('.c').css({"background":"white", "color":"black"});
});
$('.d').hover(
  function(){
        $('.d').css({"background":"white", "color":"#00b8ae"});
  },function(){
        $('.d').css({"background":"white", "color":"black"});
});
$('.InducCond1').hover(
  function(){
        $('.InducCond1').css({"background":"white", "color":"#a600d4"});
  },function(){
        $('.InducCond1').css({"background":"white", "color":"black"});
});
$('.InducCond2').hover(
  function(){
        $('.InducCond2').css({"background":"white", "color":"#d40078"});
  },function(){
        $('.InducCond2').css({"background":"white", "color":"black"});
});
$('.LatPrior').hover(
  function(){
        $('.LatPrior').css({"background":"white", "color":"#7a6b04"});
  },function(){
        $('.LatPrior').css({"background":"white", "color":"black"});
});
$('.BayesPrior').hover(
  function(){
        $('.BayesPrior').css({"background":"white", "color":"red"});
  },function(){
        $('.BayesPrior').css({"background":"white", "color":"black"});
});
$('.BayesLike').hover(
  function(){
        $('.BayesLike').css({"background":"white", "color":"#0cb500"});
  },function(){
        $('.BayesLike').css({"background":"white", "color":"black"});
});
$('.PostPred').hover(
  function(){
        $('.PostPred').css({"background":"white", "color":"#00a6ff"});
  },function(){
        $('.PostPred').css({"background":"white", "color":"black"});
});
</script>
Key assumptions: <br>
<br>
1. The relationship between $f$ and $u$ is partially independent. <br>
2. The relationship between $f*$ and $u$ is exact.<br>
<br>
Where
<table style="margin-left: auto; margin-right: auto;">
    <tr style="background-color:white;font-size:16px">
        <td class = "LatPrior">$$u \sim \mathcal{N}(0,K_{u,u})$$</td>
    </tr>
</table>
This implies that the approximate inducing conditionals are:
<table style="margin-left: auto; margin-right: auto;table-layout:fixed;font-size:16px">
    <tr style="background-color:white">
        <td class = "InducCond1">$$q_{PITC}(f|u)$$</td>
        <td >$$=$$</td>
        <td style="width:110px">$$\mathcal{N}(K_{f,u}K_{u,u}^{-1}u$$</td>
        <td >$$,$$</td>
        <td style="width:210px">$$blockdiag[K_{f,f} - Q_{f,f}]$$</td>
        <td >$$)$$</td>
    </tr>
</table>
<table style="margin-left: auto; margin-right: auto;table-layout:fixed;font-size:16px">
    <tr style="background-color:white">
        <td class = "InducCond2" style="width:110px">$$q_{PITC}(f_*|u)$$</td>
        <td >$$=$$</td>
        <td class = "InducCond2" style="width:70px">$$p(f_*|u)$$</td>
        <td >$$=$$</td>
        <td >$$\mathcal{N}($$</td>
        <td style="width:50px">$$K_{*,u}K_{u,u}^{-1}u$$</td>
        <td >$$,$$</td>
        <td >$$K_{u,u}$$</td>
        <td >$$-$$</td>
        <td >$$Q_{*,*}$$</td>
        <td >$$)$$</td>
    </tr>
</table>
Therefore, the inducing prior is given by:
<table style="margin-left: auto; margin-right: auto;table-layout:fixed;">
    <tr>
        <th colspan="11" style="text-align: center;">PITC (Noiseless)</th>
    </tr>
    <tr style="background-color:white;">
        <td rowspan = 2 class = "BayesPrior" >$$\Bigg[ \matrix{ f \cr f_*} \Bigg]$$</td>
        <td rowspan = 2 >$$\sim N \Bigg($$</td>
        <td rowspan = 2 >$$\Bigg[$$</td>
        <td >$$0$$</td>
        <td rowspan = 2 >$$\Bigg]$$</td>
        <td rowspan = 2 style="font-size:15px">,</td>
        <td rowspan = 2 >$$\Bigg[$$</td>
        <td class = "a" style="width:200px">$$Q_{f,f} - blockdiag[Q_{f,f} - K_{f,f}]$$</td>
        <td class = "b" >$$Q_{f,*}$$</td>
        <td rowspan = 2 >$$\Bigg]$$</td>
        <td rowspan = 2 >$$\Bigg)$$</td>
    </tr>
    <tr style="background-color:white;">
        <td >$$0$$</td>
        <td class = "c" >$$Q_{*,f}$$</td>
        <td class = "d" >$$K_{*,*}$$</td>
    </tr>
</table>
With the exact likelihood $p(y|f)$
<table style="margin-left: auto; margin-right: auto;table-layout:fixed;">
    <tr>
        <th colspan="11" style="text-align: center;">PITC (Noisy)</th>
    </tr>
    <tr style="background-color:white;">
        <td rowspan = 2 class = "BayesPrior" >$$\Bigg[ \matrix{ y \cr f_*} \Bigg]$$</td>
        <td rowspan = 2 >$$\sim N \Bigg($$</td>
        <td rowspan = 2 >$$\Bigg[$$</td>
        <td >$$0$$</td>
        <td rowspan = 2 >$$\Bigg]$$</td>
        <td rowspan = 2 style="font-size:15px">,</td>
        <td rowspan = 2 >$$\Bigg[$$</td>
        <td class = "BayesLike" >$$Q_{f,f} + \Lambda $$</td>
        <td class = "b" >$$Q_{f,*}$$</td>
        <td rowspan = 2 >$$\Bigg]$$</td>
        <td rowspan = 2 >$$\Bigg)$$</td>
    </tr>
    <tr style="background-color:white;">
        <td >$$0$$</td>
        <td class = "c" >$$Q_{*,f}$$</td>
        <td class = "d" >$$K_{*,*}$$</td>
    </tr>
</table>
Where $$\Lambda = blockdiag[K_{f,f} - Q_{f,f} + \sigma_n^2 I]$$<br>
Using the Property of Gaussians, the posterior predictive distribution is:
<table style="margin-left: auto; margin-right: auto;">
    <tr style="background-color:white;table-layout:fixed;font-size:16px">
        <td class = "PostPred" style="width:110px">$$q_{PITC}(f_*|y)$$</td>
        <td >$$=N($$</td>
        <td class = "c">$$Q_{*,f}$$</td>
        <td class = "BayesLike" style="width:10px">$$(Q_{f,f} + \Lambda)^{-1}$$</td>
        <td >$$y$$</td>
        <td >,</td>
        <td class = "d">$$K_{*,*}$$</td>
        <td >$$-$$</td>
        <td class = "c">$$Q_{*,f}$$</td>
        <td class = "BayesLike" style="width:10px">$$(Q_{f,f} + \Lambda)^{-1}$$</td>
        <td class = "b">$$Q_{f,*}$$</td>
        <td >$$)$$</td>
    </tr>
</table>
A computationally efficient representation of the posterior predictive prediction is:
<table style="margin-left: auto; table-layout:fixed; margin-right: auto;">
    <tr style="background-color:white;table-layout:fixed;font-size:16px">
        <td class = "PostPred">$$q_{FITC}(f_*|y)$$</td>
        <td >$$=\mathcal{N}($$</td>
        <td style="width:10px">$$\sigma_n^{-2} K_{*,u} \Sigma K_{u,f} \Lambda^{-1} y$$</td>
        <td >,</td>
        <td style="width:10px">$$K_{*,*} - Q_{*,*} + K_{*,u} \Sigma K_{u,*}$$</td>
        <td >$$)$$</td>
    </tr>
</table>
Where $$\Sigma = (K_{u,u} + K_{u,f}\Lambda^{-1}K_{f,u})^{-1}$$
''')
# Out:
# <script>
# $('.a').hover(
#   function(){
#         $('.a').css({"background":"white", "color":"blue"});
#   },function(){
#         $('.a').css({"background":"white", "color":"black"});
# });
# $('.b').hover(
#   function(){
#         $('.b').css({"background":"white", "color":"green"});
#   },function(){
#         $('.b').css({"background":"white", "color":"black"});
# });
# $('.c').hover(
#   function(){
#         $('.c').css({"background":"white", "color":"#ab4d00"});
#   },function(){
#         $('.c').css({"background":"white", "color":"black"});
# });
# $('.d').hover(
#   function(){
#         $('.d').css({"background":"white", "color":"#00b8ae"});
#   },function(){
#         $('.d').css({"background":"white", "color":"black"});
# });
# $('.InducCond1').hover(
#   function(){
#         $('.InducCond1').css({"background":"white", "color":"#a600d4"});
#   },function(){
#         $('.InducCond1').css({"background":"white", "color":"black"});
# });
# $('.InducCond2').hover(
# ...

# %% [markdown]
# Note:<br>
# The computational complexity of this method is dependent on the blocking structure imposed in the training conditional. By choosing $k = \frac{n}{m}$ blocks, each of size $m \times m$, the computational complexity is $O(m^2n)$. PITC does not  correspond exactly to a Gaussian Process.

# %% [markdown]
# Compare: <br>
# SoD <br>
# SoR <br>
# DTC <br>
# FITC <br>
# PITC <br>
# Detail the inducing conditionals, priors and complexity and whether it is GP

# %% [markdown]
# Again detail the posterior predictive distribution

# %% [markdown]
# Link to why complexity is lower (economical representaion of post) - Detaile the matrix inversion lemma, also known as the Woodbury, Sherman & Morrison formula

# %% [markdown]
# ## Choice of Inducing Variables (optimisation)

# %% [markdown]
# Maximise marginal likelihood with respect to inducing points (show the integral and log marginal likelihood) and table showing the delta of each approximation method

# %% [markdown]
# ## References and Useful Links
