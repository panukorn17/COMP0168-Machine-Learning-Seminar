# %% [markdown]
# # Approximate GP Demo

# %%
hide_toggle(for_next=True)
# Out:
#         <script>
#             function code_toggle_12852139502243874006() {
#                 $('div.cell.code_cell.rendered.selected').next().find('div.input').toggle();
#             }
#
#             $('div.cell.code_cell.rendered.selected').find("div.input").hide();
#         </script>
#
#         <a href="javascript:code_toggle_12852139502243874006()">Toggle show/hide next cell</a>

# %%
from IPython.display import HTML
import random
def hide_toggle(for_next=False):
    this_cell = """$('div.cell.code_cell.rendered.selected')"""
    next_cell = this_cell + '.next()'

    toggle_text = 'Toggle show/hide'  # text shown on toggle link
    target_cell = this_cell  # target cell to control with toggle
    js_hide_current = ''  # bit of JS to permanently hide code in current cell (only when toggling next cell)

    if for_next:
        target_cell = next_cell
        toggle_text += ' next cell'
        js_hide_current = this_cell + '.find("div.input").hide();'

    js_f_name = 'code_toggle_{}'.format(str(random.randint(1,2**64)))

    html = """
        <script>
            function {f_name}() {{
                {cell_selector}.find('div.input').toggle();
            }}

            {js_hide_current}
        </script>

        <a href="javascript:{f_name}()">{toggle_text}</a>
    """.format(
        f_name=js_f_name,
        cell_selector=target_cell,
        js_hide_current=js_hide_current, 
        toggle_text=toggle_text
    )

    return HTML(html)

# %%
hide_toggle(for_next=True)
# Out:
#         <script>
#             function code_toggle_5679712266022146395() {
#                 $('div.cell.code_cell.rendered.selected').next().find('div.input').toggle();
#             }
#
#             $('div.cell.code_cell.rendered.selected').find("div.input").hide();
#         </script>
#
#         <a href="javascript:code_toggle_5679712266022146395()">Toggle show/hide next cell</a>

# %%
# %%html
# <script>
# $('.a').hover(
#   function(){
#         $('.a').css({"background":"blue", "color":"white"});
#   },function(){
#         $('.a').css({"background":"white", "color":"black"});
# });
# $('.b').hover(
#   function(){
#         $('.b').css({"background":"green", "color":"white"});
#   },function(){
#         $('.b').css({"background":"white", "color":"black"});
# });
# $('.c').hover(
#   function(){
#         $('.c').css({"background":"red", "color":"white"});
#   },function(){
#         $('.c').css({"background":"white", "color":"black"});
# });
# $('.d').hover(
#   function(){
#         $('.d').css({"background":"yellow"});
#   },function(){
#         $('.d').css({"background":"white"});
# });
# $('.e').hover(
#   function(){
#         $('.e').css({"background":"#fcd4ff"});
#   },function(){
#         $('.e').css({"background":"white"});
# });
# </script>
# <style>
# .a {
#     background-color:white;
# }
# </style>
# <table>
#     <tr>
#         <th colspan="5" style="text-align: center;">GP</th>
#         <th colspan="2" style="text-align: center;">Approximation</th>
#     </tr>
#     <tr style="background-color:white;">
#         <td rowspan = 2 class = "e" >$$\begin{bmatrix}f \\f^* \end{bmatrix}$$</td>
#         <td rowspan = 2 >$$\sim N \Bigg($$</td>
#         <td class = "a" >$$K(X,X)$$</td>
#         <td class = "b" >$$K(X,X^*)$$</td>
#         <td rowspan = 2 >$$\Bigg)$$</td>
#         <td >Approximate</td>
#         <td class = "e" >$p(f,f^*)$</td>
#     </tr>
#     <tr style="background-color:white;">
#         <td class = "c" >$$K(X^*,X)$$</td>
#         <td class = "d" >$$K(X^*,X^*)$$</td>
#         <td > With</td>
#         <td class = "e" >$q(f,f^*)$</td>
#     </tr>
# </table>
# <table>
#     <tr>
#         <th colspan="12" style="text-align: center;">Exact Posterior predictive distribution (Noiseless)</th>
#     </tr>
#     <tr style="background-color:white;">
#         <td >$$P(f^*|f)$$</td>
#         <td >$$=N\big($$</td>
#         <td class = "c">$$A$$</td>
#         <td class = "a">$$C^{-1}$$</td>
#         <td >$$f$$</td>
#         <td style="font-size:15px">,</td>
#         <td class = "d">$$D$$</td>
#         <td >$$-$$</td>
#         <td class = "c">$$A$$</td>
#         <td class = "a">$$C^{-1}$$</td>
#         <td class = "b">$$A^T$$</td>
#         <td >$$\big)$$</td>
#     </tr>
# </table>
# Out:
# <script>
# $('.a').hover(
#   function(){
#         $('.a').css({"background":"blue", "color":"white"});
#   },function(){
#         $('.a').css({"background":"white", "color":"black"});
# });
# $('.b').hover(
#   function(){
#         $('.b').css({"background":"green", "color":"white"});
#   },function(){
#         $('.b').css({"background":"white", "color":"black"});
# });
# $('.c').hover(
#   function(){
#         $('.c').css({"background":"red", "color":"white"});
#   },function(){
#         $('.c').css({"background":"white", "color":"black"});
# });
# $('.d').hover(
#   function(){
#         $('.d').css({"background":"yellow"});
#   },function(){
#         $('.d').css({"background":"white"});
# });
# $('.e').hover(
#   function(){
#         $('.e').css({"background":"#fcd4ff"});
#   },function(){
#         $('.e').css({"background":"white"});
# });
# </script>
# <style>
# .a {
#     background-color:white;
# }
# </style>
# <table>
#     <tr>
#         <th colspan="5" style="text-align: center;">GP</th>
#         <th colspan="2" style="text-align: center;">Approximation</th>
#     </tr>
#     <tr style="background-color:white;">
#         <td rowspan = 2 class = "e" >$$\begin{bmatrix}f \\f^* \end{bmatrix}$$</td>
#         <td rowspan = 2 >$$\sim N \Bigg($$</td>
#         <td class = "a" >$$K(X,X)$$</td>
#         <td class = "b" >$$K(X,X^*)$$</td>
#         <td rowspan = 2 >$$\Bigg)$$</td>
#         <td >Approximate</td>
#         <td class = "e" >$p(f,f^*)$</td>
#     </tr>
#     <tr style="background-color:white;">
#         <td class = "c" >$$K(X^*,X)$$</td>
#         <td class = "d" >$$K(X^*,X^*)$$</td>
#         <td > With</td>
#         <td class = "e" >$q(f,f^*)$</td>
#     </tr>
# </table>
# <table>
#     <tr>
#         <th colspan="12" style="text-align: center;">Exact Posterior predictive distribution (Noiseless)</th>
#     </tr>
#     <tr style="background-color:white;">
#         <td >$$P(f^*|f)$$</td>
#         <td >$$=N\big($$</td>
#         <td class = "c">$$A$$</td>
#         <td class = "a">$$C^{-1}$$</td>
#         <td >$$f$$</td>
#         <td style="font-size:15px">,</td>
#         <td class = "d">$$D$$</td>
#         <td >$$-$$</td>
#         <td class = "c">$$A$$</td>
#         <td class = "a">$$C^{-1}$$</td>
#         <td class = "b">$$A^T$$</td>
#         <td >$$\big)$$</td>
#     </tr>
# </table>

# %%
hide_toggle(for_next=True)
# Out:
#         <script>
#             function code_toggle_7617123090076692586() {
#                 $('div.cell.code_cell.rendered.selected').next().find('div.input').toggle();
#             }
#
#             $('div.cell.code_cell.rendered.selected').find("div.input").hide();
#         </script>
#
#         <a href="javascript:code_toggle_7617123090076692586()">Toggle show/hide next cell</a>

# %%
# %%html
# <script>
# $('.a').hover(
#   function(){
#         $('.a').css({"background":"blue", "color":"white"});
#   },function(){
#         $('.a').css({"background":"white", "color":"black"});
# });
# $('.b').hover(
#   function(){
#         $('.b').css({"background":"green", "color":"white"});
#   },function(){
#         $('.b').css({"background":"white", "color":"black"});
# });
# $('.c').hover(
#   function(){
#         $('.c').css({"background":"red", "color":"white"});
#   },function(){
#         $('.c').css({"background":"white", "color":"black"});
# });
# $('.d').hover(
#   function(){
#         $('.d').css({"background":"yellow"});
#   },function(){
#         $('.d').css({"background":"white"});
# });
# $('.e').hover(
#   function(){
#         $('.e').css({"background":"#fcd4ff"});
#   },function(){
#         $('.e').css({"background":"white"});
# });
# </script>
# <table>
#     <tr>
#         <th colspan="12" style="text-align: center;">Exact Posterior predictive distribution (Noiseless)</th>
#     </tr>
#     <tr style="background-color:white;">
#         <td >$$P(f^*|f)$$</td>
#         <td >$$=N\big($$</td>
#         <td class = "c">$$A$$</td>
#         <td class = "a">$$C^{-1}$$</td>
#         <td >$$f$$</td>
#         <td style="font-size:15px">,</td>
#         <td class = "d">$$D$$</td>
#         <td >$$-$$</td>
#         <td class = "c">$$A$$</td>
#         <td class = "a">$$C^{-1}$$</td>
#         <td class = "b">$$A^T$$</td>
#         <td >$$\big)$$</td>
#     </tr>
# </table>
# Out:
# <script>
# $('.a').hover(
#   function(){
#         $('.a').css({"background":"blue", "color":"white"});
#   },function(){
#         $('.a').css({"background":"white", "color":"black"});
# });
# $('.b').hover(
#   function(){
#         $('.b').css({"background":"green", "color":"white"});
#   },function(){
#         $('.b').css({"background":"white", "color":"black"});
# });
# $('.c').hover(
#   function(){
#         $('.c').css({"background":"red", "color":"white"});
#   },function(){
#         $('.c').css({"background":"white", "color":"black"});
# });
# $('.d').hover(
#   function(){
#         $('.d').css({"background":"yellow"});
#   },function(){
#         $('.d').css({"background":"white"});
# });
# $('.e').hover(
#   function(){
#         $('.e').css({"background":"#fcd4ff"});
#   },function(){
#         $('.e').css({"background":"white"});
# });
# </script>
# <table>
#     <tr>
#         <th colspan="12" style="text-align: center;">Exact Posterior predictive distribution (Noiseless)</th>
#     </tr>
#     <tr style="background-color:white;">
#         <td >$$P(f^*|f)$$</td>
#         <td >$$=N\big($$</td>
#         <td class = "c">$$A$$</td>
#         <td class = "a">$$C^{-1}$$</td>
#         <td >$$f$$</td>
#         <td style="font-size:15px">,</td>
#         <td class = "d">$$D$$</td>
#         <td >$$-$$</td>
#         <td class = "c">$$A$$</td>
#         <td class = "a">$$C^{-1}$$</td>
#         <td class = "b">$$A^T$$</td>
#         <td >$$\big)$$</td>
#     </tr>
# </table>
