# %% [markdown]
# <h1 style="text-align:center; font-size:40px"><u>Approximate Gaussian Processes Coding Demo</u></h1>

# %% [markdown]
# This coding demo has been adapted from the excellent Gaussian Process Summer School (2018) lab 2 written by _Fariba Yousefi, Juan José Giraldo, and Wil Ward._ You can find the original labs in this <a href="https://github.com/gpschool/gpss18" target="_blank">Github repository</a>.
#
# In this demo, we will go through two methods for approximating Gaussian Processes (GP) regression on a small and large dataset. The first method is the Deterministic Training Conditional (DTC) Approximation and the second method is the stochastic variational GP approximation. We will also be introducing the theory behind optimising for inducing points. In our theory demo, we have assumed that the inducing points have been provided.
#
# This notebook uses `GPy` for handling the regression model and likelihoods.

# %% [markdown]
# ##  1. Getting started
#
# You should be using Python 3.5 (or above), and have `GPy` installed.
#
# We will use `numpy` for maths functionality, `pyplot` for plotting, and `GPy` for Gaussian processes. The documentation for `GPy` is available at [gpy.readthedocs.io](http://gpy.readthedocs.io/en/deploy/)

# %%
# Support for maths
import numpy as np
# Plotting tools
from matplotlib import pyplot as plt
# we use the following for plotting figures in jupyter
# %matplotlib inline
import time

import warnings
warnings.filterwarnings('ignore')

# GPy: Gaussian processes library
import GPy

# %% [markdown]
# We will use this plotting function to help with visualising our GP regression outputs:

# %%
def plot_gp(X, m, C, training_points=None):
    """ Plotting utility to plot a GP fit with 95% confidence interval """
    # Plot 95% confidence interval 
    plt.fill_between(X[:,0],
                     m[:,0] - 1.96*np.sqrt(np.diag(C)), # 95% confidence interval of a Gaussian is
                     m[:,0] + 1.96*np.sqrt(np.diag(C)), # .. contained within mean +/- 1.96*s.d.
                     alpha=0.5)
    # Plot GP mean and initial training points
    plt.plot(X, m, "-")
    plt.legend(labels=["GP fit"])
    
    plt.xlabel("x"), plt.ylabel("f")
    
    # Plot training points if included
    if training_points is not None:
        X_, Y_ = training_points
        plt.plot(X_, Y_, "kx", mew=2)
        plt.legend(labels=["GP fit", "sample points"])

# %% [markdown]
# ### Full versus Sparse Gaussian Process Regression
#
# In the following example, we will simulate some observations sampled from a GP, and compare the results of sparse and full regression.
#
# First we will generate $N=50$ samples from a GP:

# %%
# This is important for reproducing the latent function
np.random.seed(40918)

# The covariance in the latent function is an RBF with l=0.2
k = GPy.kern.RBF(1, variance=1., lengthscale=0.1)

# Create a smooth GP latent function
N = 50
X = np.sort(np.random.rand(N, 1), 0)
y = np.random.multivariate_normal(np.zeros(N), k.K(X,X) + 0.01*np.eye(N))[:, None]

# %% [markdown]
# <span style="color:red">Teddy Note: We could tweak this initialisation</span> <br>
# While $n=50$ is not a _huge_ number of data, this example will show that we can get a reasonably accurate fit with only a small number of inducing variables, $m=3$. This will reduce the complexity of full GP regression, $\mathscr{O}(n^3)$, to $\mathscr{O}(m^2n)$, which is clearly a useful reduction in computational requirements &ndash; even in this basic example, we can see $n \times m^2 = 450 \ll n^3 = 125000$.
#
# We make use of the `SparseGPRegression` model which, like the `GPRegression` model, has sensible defaults that we don't need to worry about for this example. The `SparseGPRegression` assumes a Gaussian likelihood and uses exact Gaussian inference. We could also define these explicitly using `core.SVGP`, which is the sparse equivalent of `core.GP` that we used above, allowing us to define the inference method, and likelihood.

# %% [markdown]
# <span style="color:red">Teddy Note: Increase the number of input datapoints</span> DONE<br>
# <span style="color:red">Teddy Note: Time vs number of input points</span> DONE<br>
# <span style="color:red">Teddy Note: Increase the number of inducing points</span> DONE<br>
# <span style="color:red">Teddy Note: Time vs number of inducing points</span> DONE<br>
# <span style="color:red">Teddy Note: Introduce theory of inducing point optimisation</span> <br>
# <span style="color:red">Teddy Note: Undertake approx GP regression</span> <br>

# %% [markdown]
# <span style="color:red">Teddy Note: maybe have the optimisation after the gp without optimisation of the inducing points and introduce the theory as per the paper as well </span>

# %% [markdown]
# **We first fit the full GP**

# %%
# Our sample space for predictions from the posterior
Xnew = np.linspace(-0.1, 1.1, 1000)[:, None]

# The covariance we used to generate the samples (assumed)
k = GPy.kern.RBF(1, variance=1., lengthscale=0.1)

# Prepare figure enviroment
plt.figure(figsize=(18, 6))

## First we fit with full GP regression
t0 = time.time()
m = GPy.models.GPRegression(X, y, kernel=k)
t1 = time.time()
m.Gaussian_noise.variance = 0.01
print('elapsed time:',t1-t0,'seconds')

# Note we don't even optimise the hyperparameters because they are known here
mean_full, Cov_full = m.predict(Xnew, full_cov=True)

# We plot our regression fit of the likelihood
plot_gp(Xnew, mean_full, Cov_full, training_points=(X, y))
plt.title("Full GP regression")
# Out:
# elapsed time: 0.00499272346496582 seconds
# Text(0.5, 1.0, 'Full GP regression')

# %% [markdown]
# **Then we fit the sparse GP using DTC and 3 random inducing points**

# %%
## Next, we define M=3 inducing points randomly within the sample space
Z = np.random.rand(3, 1)

# We fit with sparse GP regression using randomly assigned inducing variables
t0 = time.time()
m = GPy.models.SparseGPRegression(X, y, Z=Z, kernel=k)
t1 = time.time()
print('elapsed time:',t1-t0,'seconds')
m.Gaussian_noise.variance = 0.01
m.Gaussian_noise.fix() # We fix the Gaussian observation noise

# We will not optimise any of the hyperparameters again
mean_sparse_rand, Cov_sparse_rand = m.predict(Xnew, full_cov=True)

# Prepare figure enviroment
plt.figure(figsize=(18, 6))
# Plot the posterior of the likelihood fit using a sparse GP
plot_gp(Xnew, mean_sparse_rand, Cov_sparse_rand, training_points=(X, y))
# Plot the randomly assigned inducing variables
plt.plot(Z, [plt.ylim()[0] for _ in Z], 'b^', mew=3)
plt.legend(labels=["sparse fit", "sample points", "random inducing locations"])
# Out:
# elapsed time: 0.008977413177490234 seconds

# %% [markdown]
# **Elapsed time vs number of observed points**<br>
# Although it may seem as though the full GP is faster, this is simply because the number of datapoints are very small, lets demonstrate how quickly the elapsed time increases when we increase the number of observed points.

# %%
# This is important for reproducing the latent function
np.random.seed(40918)
N = np.linspace(50, 500, 45, dtype=int)
gp_full_time = np.zeros(len(N))
gp_sparse_time = np.zeros(len(N))

for i in range(len(N)):
    X = np.sort(np.random.rand(N[i], 1), 0)
    y = np.random.multivariate_normal(np.zeros(N[i]), k.K(X,X) + 0.01*np.eye(N[i]))[:, None]
    
    ## First we fit with full GP regression
    t0_full = time.time()
    m = GPy.models.GPRegression(X, y, kernel=k)
    t1_full = time.time()
    gp_full_time[i] = t1_full - t0_full
    
    ## Now we fit with sparse GP regression
    t0_sparse = time.time()
    m = GPy.models.SparseGPRegression(X, y, Z=Z, kernel=k)
    t1_sparse = time.time()
    gp_sparse_time[i] = t1_sparse - t0_sparse
    
    print('Full GP elapsed time: %.4f seconds | Sparse GP elapsed time: %.4f seconds'% (gp_full_time[i], gp_sparse_time[i]))

# We can plot this
# Prepare figure enviroment
plt.figure(figsize=(18, 6))
line_full, = plt.plot(N,gp_full_time,label="Full GP")
line_sparse, = plt.plot(N,gp_sparse_time,label="Sparse GP")
plt.legend(handles=[line_full, line_sparse])
plt.xlabel("Number of observered points")
plt.ylabel("Elapsed Time (s)")
plt.show()
# Out:
# Full GP elapsed time: 0.0080 seconds | Sparse GP elapsed time: 0.0110 seconds
# Full GP elapsed time: 0.0070 seconds | Sparse GP elapsed time: 0.0060 seconds
# Full GP elapsed time: 0.0060 seconds | Sparse GP elapsed time: 0.0090 seconds
# Full GP elapsed time: 0.0060 seconds | Sparse GP elapsed time: 0.0070 seconds
# Full GP elapsed time: 0.0050 seconds | Sparse GP elapsed time: 0.0090 seconds
# Full GP elapsed time: 0.0070 seconds | Sparse GP elapsed time: 0.0090 seconds
# Full GP elapsed time: 0.0080 seconds | Sparse GP elapsed time: 0.0090 seconds
# Full GP elapsed time: 0.0090 seconds | Sparse GP elapsed time: 0.0090 seconds
# Full GP elapsed time: 0.0090 seconds | Sparse GP elapsed time: 0.0090 seconds
# Full GP elapsed time: 0.0080 seconds | Sparse GP elapsed time: 0.0090 seconds
# Full GP elapsed time: 0.0090 seconds | Sparse GP elapsed time: 0.0100 seconds
# Full GP elapsed time: 0.0110 seconds | Sparse GP elapsed time: 0.0090 seconds
# Full GP elapsed time: 0.0100 seconds | Sparse GP elapsed time: 0.0090 seconds
# Full GP elapsed time: 0.0100 seconds | Sparse GP elapsed time: 0.0090 seconds
# Full GP elapsed time: 0.0100 seconds | Sparse GP elapsed time: 0.0100 seconds
# Full GP elapsed time: 0.0110 seconds | Sparse GP elapsed time: 0.0090 seconds
# Full GP elapsed time: 0.0110 seconds | Sparse GP elapsed time: 0.0090 seconds
# Full GP elapsed time: 0.0120 seconds | Sparse GP elapsed time: 0.0100 seconds
# Full GP elapsed time: 0.0160 seconds | Sparse GP elapsed time: 0.0090 seconds
# Full GP elapsed time: 0.0150 seconds | Sparse GP elapsed time: 0.0090 seconds
# Full GP elapsed time: 0.0160 seconds | Sparse GP elapsed time: 0.0100 seconds
# Full GP elapsed time: 0.0150 seconds | Sparse GP elapsed time: 0.0090 seconds
# Full GP elapsed time: 0.0160 seconds | Sparse GP elapsed time: 0.0090 seconds
# Full GP elapsed time: 0.0180 seconds | Sparse GP elapsed time: 0.0100 seconds
# Full GP elapsed time: 0.0189 seconds | Sparse GP elapsed time: 0.0090 seconds
# Full GP elapsed time: 0.0199 seconds | Sparse GP elapsed time: 0.0110 seconds
# Full GP elapsed time: 0.0209 seconds | Sparse GP elapsed time: 0.0120 seconds
# Full GP elapsed time: 0.0239 seconds | Sparse GP elapsed time: 0.0100 seconds
# Full GP elapsed time: 0.0239 seconds | Sparse GP elapsed time: 0.0100 seconds
# Full GP elapsed time: 0.0229 seconds | Sparse GP elapsed time: 0.0120 seconds
# Full GP elapsed time: 0.0249 seconds | Sparse GP elapsed time: 0.0100 seconds
# Full GP elapsed time: 0.0309 seconds | Sparse GP elapsed time: 0.0110 seconds
# Full GP elapsed time: 0.0339 seconds | Sparse GP elapsed time: 0.0110 seconds
# Full GP elapsed time: 0.0349 seconds | Sparse GP elapsed time: 0.0110 seconds
# Full GP elapsed time: 0.0359 seconds | Sparse GP elapsed time: 0.0100 seconds
# Full GP elapsed time: 0.0379 seconds | Sparse GP elapsed time: 0.0100 seconds
# Full GP elapsed time: 0.0409 seconds | Sparse GP elapsed time: 0.0110 seconds
# Full GP elapsed time: 0.0419 seconds | Sparse GP elapsed time: 0.0100 seconds
# Full GP elapsed time: 0.0429 seconds | Sparse GP elapsed time: 0.0120 seconds
# Full GP elapsed time: 0.0469 seconds | Sparse GP elapsed time: 0.0120 seconds
# Full GP elapsed time: 0.0519 seconds | Sparse GP elapsed time: 0.0110 seconds
# Full GP elapsed time: 0.0568 seconds | Sparse GP elapsed time: 0.0110 seconds
# Full GP elapsed time: 0.0519 seconds | Sparse GP elapsed time: 0.0100 seconds
# Full GP elapsed time: 0.0509 seconds | Sparse GP elapsed time: 0.0100 seconds
# Full GP elapsed time: 0.0529 seconds | Sparse GP elapsed time: 0.0120 seconds

# %% [markdown]
# **Elapsed time vs number of induced points**<br>
# It is clear from the above figure that elapsed time to fit a full GP model increases rapidly with an increasing number of observed points. On the other hand, the elapsed time to fit a sparse GP model does not increase up to 500 observed points. Recall that the time complexity to fit a GP model using DTC is $\mathscr{O}(m^2n)$ therefore, we will demonstrate how the elapsed time to fit a sparse GP model increases with an increasing number of inducing points and a fixed number of input points.

# %%
# This is important for reproducing the latent function
np.random.seed(40918)
N = 500
M = np.linspace(1, 200, 100, dtype=int)
gp_sparse_time = np.zeros(len(M))

X = np.sort(np.random.rand(N, 1), 0)
y = np.random.multivariate_normal(np.zeros(N), k.K(X,X) + 0.01*np.eye(N))[:, None]

## First we fit with full GP regression
t0_full = time.time()
m = GPy.models.GPRegression(X, y, kernel=k)
t1_full = time.time()
gp_full_time = t1_full - t0_full
    
for i in range(len(M)):
    
    ## Now we fit with sparse GP regression
    t0_sparse = time.time()
    m = GPy.models.SparseGPRegression(X, y, Z=np.random.rand(M[i], 1), kernel=k)
    t1_sparse = time.time()
    gp_sparse_time[i] = t1_sparse - t0_sparse
    
    print('Sparse GP elapsed time with %s inducing points is: %.4f seconds'% (M[i], gp_sparse_time[i]))

# We can plot this
# Prepare figure enviroment
plt.figure(figsize=(18, 6))
line_full, = plt.plot(M,[gp_full_time]*len(M),label="Full GP")
line_sparse, = plt.plot(M,gp_sparse_time,label="Sparse GP")
plt.legend(handles=[line_full, line_sparse])
plt.xlabel("Number of inducing points")
plt.ylabel("Elapsed Time (s)")
plt.show()
# Out:
# Sparse GP elapsed time with 1 inducing points is: 0.0110 seconds
# Sparse GP elapsed time with 3 inducing points is: 0.0100 seconds
# Sparse GP elapsed time with 5 inducing points is: 0.0100 seconds
# Sparse GP elapsed time with 7 inducing points is: 0.0100 seconds
# Sparse GP elapsed time with 9 inducing points is: 0.0120 seconds
# Sparse GP elapsed time with 11 inducing points is: 0.0100 seconds
# Sparse GP elapsed time with 13 inducing points is: 0.0100 seconds
# Sparse GP elapsed time with 15 inducing points is: 0.0110 seconds
# Sparse GP elapsed time with 17 inducing points is: 0.0110 seconds
# Sparse GP elapsed time with 19 inducing points is: 0.0110 seconds
# Sparse GP elapsed time with 21 inducing points is: 0.0110 seconds
# Sparse GP elapsed time with 23 inducing points is: 0.0120 seconds
# Sparse GP elapsed time with 25 inducing points is: 0.0120 seconds
# Sparse GP elapsed time with 27 inducing points is: 0.0120 seconds
# Sparse GP elapsed time with 29 inducing points is: 0.0120 seconds
# Sparse GP elapsed time with 31 inducing points is: 0.0100 seconds
# Sparse GP elapsed time with 33 inducing points is: 0.0080 seconds
# Sparse GP elapsed time with 35 inducing points is: 0.0100 seconds
# Sparse GP elapsed time with 37 inducing points is: 0.0100 seconds
# Sparse GP elapsed time with 39 inducing points is: 0.0090 seconds
# Sparse GP elapsed time with 41 inducing points is: 0.0090 seconds
# Sparse GP elapsed time with 43 inducing points is: 0.0100 seconds
# Sparse GP elapsed time with 45 inducing points is: 0.0080 seconds
# Sparse GP elapsed time with 47 inducing points is: 0.0080 seconds
# Sparse GP elapsed time with 49 inducing points is: 0.0080 seconds
# Sparse GP elapsed time with 51 inducing points is: 0.0090 seconds
# Sparse GP elapsed time with 53 inducing points is: 0.0080 seconds
# Sparse GP elapsed time with 55 inducing points is: 0.0110 seconds
# Sparse GP elapsed time with 57 inducing points is: 0.0090 seconds
# Sparse GP elapsed time with 59 inducing points is: 0.0090 seconds
# Sparse GP elapsed time with 61 inducing points is: 0.0090 seconds
# Sparse GP elapsed time with 63 inducing points is: 0.0100 seconds
# Sparse GP elapsed time with 65 inducing points is: 0.0100 seconds
# Sparse GP elapsed time with 67 inducing points is: 0.0099 seconds
# Sparse GP elapsed time with 69 inducing points is: 0.0090 seconds
# Sparse GP elapsed time with 71 inducing points is: 0.0100 seconds
# Sparse GP elapsed time with 73 inducing points is: 0.0140 seconds
# Sparse GP elapsed time with 75 inducing points is: 0.0120 seconds
# Sparse GP elapsed time with 77 inducing points is: 0.0130 seconds
# Sparse GP elapsed time with 79 inducing points is: 0.0120 seconds
# Sparse GP elapsed time with 81 inducing points is: 0.0150 seconds
# Sparse GP elapsed time with 83 inducing points is: 0.0180 seconds
# Sparse GP elapsed time with 85 inducing points is: 0.0180 seconds
# Sparse GP elapsed time with 87 inducing points is: 0.0180 seconds
# Sparse GP elapsed time with 89 inducing points is: 0.0180 seconds
# Sparse GP elapsed time with 91 inducing points is: 0.0189 seconds
# Sparse GP elapsed time with 93 inducing points is: 0.0199 seconds
# Sparse GP elapsed time with 95 inducing points is: 0.0189 seconds
# Sparse GP elapsed time with 97 inducing points is: 0.0199 seconds
# Sparse GP elapsed time with 99 inducing points is: 0.0189 seconds
# Sparse GP elapsed time with 101 inducing points is: 0.0189 seconds
# Sparse GP elapsed time with 103 inducing points is: 0.0180 seconds
# Sparse GP elapsed time with 105 inducing points is: 0.0189 seconds
# Sparse GP elapsed time with 107 inducing points is: 0.0189 seconds
# Sparse GP elapsed time with 109 inducing points is: 0.0199 seconds
# Sparse GP elapsed time with 111 inducing points is: 0.0189 seconds
# Sparse GP elapsed time with 113 inducing points is: 0.0189 seconds
# Sparse GP elapsed time with 115 inducing points is: 0.0199 seconds
# Sparse GP elapsed time with 117 inducing points is: 0.0219 seconds
# Sparse GP elapsed time with 119 inducing points is: 0.0199 seconds
# Sparse GP elapsed time with 121 inducing points is: 0.0209 seconds
# Sparse GP elapsed time with 123 inducing points is: 0.0219 seconds
# Sparse GP elapsed time with 125 inducing points is: 0.0219 seconds
# Sparse GP elapsed time with 127 inducing points is: 0.0219 seconds
# Sparse GP elapsed time with 129 inducing points is: 0.0219 seconds
# Sparse GP elapsed time with 131 inducing points is: 0.0239 seconds
# Sparse GP elapsed time with 133 inducing points is: 0.0229 seconds
# Sparse GP elapsed time with 135 inducing points is: 0.0349 seconds
# Sparse GP elapsed time with 137 inducing points is: 0.0239 seconds
# Sparse GP elapsed time with 139 inducing points is: 0.0229 seconds
# Sparse GP elapsed time with 141 inducing points is: 0.0229 seconds
# Sparse GP elapsed time with 143 inducing points is: 0.0249 seconds
# Sparse GP elapsed time with 145 inducing points is: 0.0279 seconds
# Sparse GP elapsed time with 147 inducing points is: 0.0279 seconds
# Sparse GP elapsed time with 149 inducing points is: 0.0269 seconds
# Sparse GP elapsed time with 151 inducing points is: 0.0279 seconds
# Sparse GP elapsed time with 153 inducing points is: 0.0269 seconds
# Sparse GP elapsed time with 155 inducing points is: 0.0269 seconds
# Sparse GP elapsed time with 157 inducing points is: 0.0269 seconds
# Sparse GP elapsed time with 159 inducing points is: 0.0269 seconds
# Sparse GP elapsed time with 161 inducing points is: 0.0269 seconds
# Sparse GP elapsed time with 163 inducing points is: 0.0269 seconds
# Sparse GP elapsed time with 165 inducing points is: 0.0289 seconds
# Sparse GP elapsed time with 167 inducing points is: 0.0289 seconds
# Sparse GP elapsed time with 169 inducing points is: 0.0289 seconds
# Sparse GP elapsed time with 171 inducing points is: 0.0289 seconds
# Sparse GP elapsed time with 173 inducing points is: 0.0279 seconds
# Sparse GP elapsed time with 175 inducing points is: 0.0329 seconds
# Sparse GP elapsed time with 177 inducing points is: 0.0279 seconds
# Sparse GP elapsed time with 179 inducing points is: 0.0319 seconds
# Sparse GP elapsed time with 181 inducing points is: 0.0309 seconds
# Sparse GP elapsed time with 183 inducing points is: 0.0299 seconds
# Sparse GP elapsed time with 185 inducing points is: 0.0329 seconds
# Sparse GP elapsed time with 187 inducing points is: 0.0339 seconds
# Sparse GP elapsed time with 189 inducing points is: 0.0339 seconds
# Sparse GP elapsed time with 191 inducing points is: 0.0379 seconds
# Sparse GP elapsed time with 193 inducing points is: 0.0389 seconds
# Sparse GP elapsed time with 195 inducing points is: 0.0339 seconds
# Sparse GP elapsed time with 197 inducing points is: 0.0359 seconds
# Sparse GP elapsed time with 200 inducing points is: 0.0359 seconds

# %%
# Our sample space for predictions from the posterior
Xnew = np.linspace(-0.1, 1.1, 1000)[:, None]

# The covariance we used to generate the samples (assumed)
k = GPy.kern.RBF(1, variance=1., lengthscale=0.1)

# Prepare figure enviroment
plt.figure(figsize=(18, 6))

plt.subplot(121)
## First we fit with full GP regression 
m = GPy.models.GPRegression(X, y, kernel=k)
m.Gaussian_noise.variance = 0.01

# Note we don't even optimise the hyperparameters because they are known here
mean_full, Cov_full = m.predict(Xnew, full_cov=True)

# We plot our regression fit of the likelihood
plot_gp(Xnew, mean_full, Cov_full, training_points=(X, y))
plt.title("Full GP regression")
plt.subplot(122)

## Next, we define M=3 inducing points randomly within the sample space
Z = np.random.rand(3, 1)

# We fit with sparse GP regression using randomly assigned inducing variables
m = GPy.models.SparseGPRegression(X, y, Z=Z, kernel=k)
m.Gaussian_noise.variance = 0.01
m.Gaussian_noise.fix() # We fix the Gaussian observation noise

# We will not optimise any of the hyperparameters again
mean_sparse_rand, Cov_sparse_rand = m.predict(Xnew, full_cov=True)

# Plot the posterior of the likelihood fit using a sparse GP
plot_gp(Xnew, mean_sparse_rand, Cov_sparse_rand, training_points=(X, y))
# Plot the randomly assigned inducing variables
plt.plot(Z, [plt.ylim()[0] for _ in Z], 'b^', mew=3)
         
## We are now going to optimise the model
# We will optimise the inducing point locations and the 
# .. kernel hyperparameters with respect to each other (remember the noise is fixed)
m.optimize()

# We predict the optimised sparse GP fit
mean_sparse_opt, Cov_sparse_opt = m.predict(Xnew, full_cov=True)

# We plot our new mean
plot_gp(Xnew, mean_sparse_opt, Cov_sparse_opt)
# Plot optimised inducing variable locations
plt.plot(m.Z, [plt.ylim()[0] for _ in m.Z], 'y^', mew=3)

# Annotate plot
plt.xlim((-0.1, 1.1)), plt.title("Sparse GP regression with 3 inducing variables")
plt.legend(labels=["sparse fit", "sample points", "random inducing locations", "optimised sparse fit", "optimised inducing locations"]);

# %% [markdown]
# With such a small number of data points, it's clearly a better option to use full Gaussian process regression here. However, our optimised sparse GP fit produces a sufficiently good fit of the data considering the small ($M=3$) number of inducing variables used. It should be clear that when we have a substantially larger number of data points $N$, using sparse GPs will provide a scalable solution when it is no longer feasible to calculate the full GP.

# %% [markdown]
# ### A Longer Example
#
# #### <span style="color:red">Note from Teddy: This method uses Stochastic Variational GPs. as per https://gpy.readthedocs.io/en/deploy/_modules/GPy/core/svgp.html , the method implemented is detailed in https://arxiv.org/ftp/arxiv/papers/1309/1309.6835.pdf </span>
#
# In the next example, we will try and use sparse GPs to approximate an unknown function for which we have a large number of (noisy) observations.
#
# Consider the function
# $$
#     f(x) = \sin(2\pi x) + \sin(25\pi x) + \sin(5\pi x) + \sin(11\pi x)
# $$
#
# We have a large number of observations, $N=5000$:
#
# $$
#     \mathbf{y} = f(\mathbf{X}) + \varepsilon,
# $$
#
# and for now, we will assume a Gaussian likelihood: $\varepsilon \sim \mathcal{N}(0, \sigma^2)$

# %%
# True latent function
f = lambda x: sum([np.sin(w*np.pi*x) for w in [2, 25, 5, 11]])

N = 5000 # large number of observations

# Random sample locations
X = np.sort(np.random.rand(N)[:,None])
# N noisy observations of the latent function with variance 0.01
y = f(X) + 0.1*np.random.randn(N, 1)

#== Plot samples
plt.figure(figsize=(14, 6))

# Plot points (since there's a lot we make them slightly transparent)
plt.plot(X, y, 'k.', mew=0.1, alpha=0.5)

# Annotate plot
plt.xlabel("$x$"), plt.ylabel("$y$")
plt.legend(labels=["%d observations" % N]);

# %% [markdown]
# Clearly, if we tried to fit full GP regression to this, we would face some problems with the sheer computational resources required for matrix inversion in the Gaussian process equations.
#
# We will use a sparse GP with a small number of inducing points, $M=20$, to try and fit the function. Given the large number of points, we will make some adjustments of the optimiser. We will cap the number of iterations to save time in the lab. These options are given to the `m.optimize()` function. We also add a small amount ($\sigma^2=10^{-6}$) of white noise to our kernel function to avoid any ill-posedness that may occur in the matrix calculations.

# %% [markdown]
# <span style="color:red">Teddy Note: perhaps have multiple plots, each of a different lengthscale and maybe use timer to try and show the effect of better inducing point initialisation? </span>

# %%
# Number of inducing variables
M = 20

# We define M inducing variables sampled uniformly throughout our input space
Z = np.linspace(0., 1., M)[:, None]
# Z = kmeans(X,M)[0]
# We assume the covariance to be an RBF, and add a white noise term for numerical stability
k = GPy.kern.RBF(1, lengthscale=0.05, name="rbf") + GPy.kern.White(1, name="white")

# Define a sparse GP with Gaussian likelihood
m = GPy.core.SVGP(
    X, y, Z,
    kernel = k,
    likelihood = GPy.likelihoods.Gaussian()
)

# We define the white noise variance to 10^-6 and fix this
m.kern.white.variance = 1.e-6
m.kern.white.fix()

# We limit the number of iterations here, to limit the maximum runtime
# .. We will also allow the optimiser to print progress messages while it is running
m.optimize(max_iters=2500, messages=1)

# Preview our sparse GP model
m
# Out:
# HBox(children=(VBox(children=(IntProgress(value=0, max=2500), HTML(value=''))), Box(children=(HTML(value=''),)…
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: SVGP<br>
# <b>Objective</b>: 5956.325557088291<br>
# <b>Number of Parameters</b>: 254<br>
# <b>Number of Optimization Parameters</b>: 253<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  SVGP.                  </b></th><th><b>              value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  inducing inputs        </td><td class=tg-right>            (20, 1)</td><td class=tg-center>           </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.rbf.variance       </td><td class=tg-right>0.08136435463702536</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.rbf.lengthscale    </td><td class=tg-right>0.01949084436761818</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.white.variance     </td><td class=tg-right>              1e-06</td><td class=tg-center> +ve fixed </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance</td><td class=tg-right> 0.5709975173043272</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  q_u_chol               </td><td class=tg-right>           (210, 1)</td><td class=tg-center>           </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  q_u_mean               </td><td class=tg-right>            (20, 1)</td><td class=tg-center>           </td><td class=tg-center>      </td></tr>
# </table>

# %%
# We create a prediction space defined over the observation space
Xnew = np.linspace(0., 1., 2000)[:, None]

# We predict a likelihood free estimate of our latent functon
mean, Cov = m.predict(Xnew)

# Set up figure environment
plt.figure(figsize=(18, 6))

# Plot the sparse GP prediction
plot_gp(Xnew, mean, Cov)

# Plot observations
plt.plot(X, y, 'k.', mew=0.1, alpha=0.5)

# Plot inducing variable locations
# .. Original inducing variables
plt.plot(Z, [plt.ylim()[0] for _ in Z], 'k^', mew=3)
# .. Optimised inducing variables
plt.plot(m.Z, [plt.ylim()[0] for _ in m.Z], 'rv', mew=3)

# Annotate plot
plt.xlim((0., 1.))
plt.title("Sparse GP with uniform inducing variables")
plt.legend(labels=["GP fit", "Observations", "Original inducing variables", "Optimised inducing variables"]);

# %% [markdown]
# ### Exercise 3
#
# (a) How do you feel about the fit? Based on what you learned in the Lab 1, what changes might you make to the kernel used?

# %% [markdown]
# <span style="color:red">Teddy answer: Change lengthscale to 0.01</span>

# %% [markdown]
# (b) In the above example, we sampled the inducing variable locations uniformly. However, we can produce a better initialisation, for example using $k$-means clustering. Using `scipy.cluster.vq.kmeans`, initalise the inducing point based on the cluster centroids. How does this improve the fit?

# %%
from scipy.cluster.vq import kmeans

# %%
# Teddy note : use this instead of default z
kmeans(X,M)[0]
# Out:
# array([[0.15934688],
#        [0.30807736],
#        [0.36048259],
#        [0.47134462],
#        [0.20593821],
#        [0.11374885],
#        [0.89032806],
#        [0.58320021],
#        [0.25556435],
#        [0.63611341],
#        [0.97612282],
#        [0.79799242],
#        [0.84476804],
#        [0.93329058],
#        [0.07058432],
#        [0.5269692 ],
#        [0.74309336],
#        [0.68939558],
#        [0.41502563],
#        [0.0230825 ]])
